# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data

import torchvision.models as models
from collections import OrderedDict

import time
import pickle
import pandas
import numpy as np 
import matplotlib.pyplot as plt   
import scipy.stats as st

import W2reg_core as W2Rcore
import W2reg_misc as W2Rmisc

import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Load pre-treated MNIST data.**
#
# The treatments make the predictions $y$ biased with respect to the variable $S$ (see the JMIV 2022 paper).

# %%
#Data loading
X_bw=pickle.load(open("X_bw_np_32186", 'rb'))
X_bw_nogen=pickle.load(open("X_bw_nogen_np_32186","rb"))
Titles_=pickle.load(open("Titles_np_32186","rb"))
Gen_=pickle.load(open("Gen_np_32186","rb"))

# %%
n=32186

Gen_=Gen_[:n]
Titles_=Titles_[:n]
X_bw=X_bw[:n]
X_bw_nogen=X_bw_nogen[:n]

Titles=[]
Gen=[]
for i in range(len(Titles_)):
    if Titles_[i]=="nurse" :
        Titles.append([1])
    else :
        Titles.append([0])
    if Gen_[i]=="F":
        Gen.append(1)
    else :
        Gen.append(0)

# %%
Gen =torch.FloatTensor(Gen)
Titles = torch.FloatTensor(Titles) 
X_bw=torch.FloatTensor(X_bw.values.tolist())
X_bw_nogen=torch.FloatTensor(X_bw_nogen.values.tolist())


X_bw_train, X_bw_test, X_bw_nogen_train, X_bw_nogen_test, Titles_train, Titles_test, Gen_train, Gen_test = train_test_split(X_bw, X_bw_nogen, Titles, Gen, test_size = 0.4, random_state=0)

# %% [markdown]
# ## With gender information

# %%
#parametres
input_size = len(X_bw_train[0])
opti_lr = 1e-3 #le pas d'apprentissage

# %%
class Logistic_Reg_model(torch.nn.Module):
    def __init__(self,input_dim):
        super(Logistic_Reg_model,self).__init__()
        self.layer1=torch.nn.Linear(input_dim,1)
    def forward(self,x):
        y_predicted=torch.sigmoid(self.layer1(x))
        return y_predicted

# %% [markdown]
# **Training phase with or without the W2 regulatization.**

# %%
EPOCHS_in = 10 
BATCH_SIZE_in = 200
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') 

#without regularisation risque Overfitting

lambdavar=0.00

model_no_reg = Logistic_Reg_model(input_size)


print('Run training - without reg') 

Lists_Results=W2Rcore.W2R_fit(model_no_reg,X_bw_train,Titles_train, Gen_train, lambdavar, EPOCHS = EPOCHS_in, BATCH_SIZE = BATCH_SIZE_in,obs_for_histo=50,DistBetween='All_predictions',DEVICE=DEVICE)

plt.figure()
plt.plot(Lists_Results['Acc'],'g--',label='Error rate')
#plt.plot(lambdavar*np.array(Lists_Results['W2']),'r-',label='$\lambda$*W2')
plt.xlabel('Iterations ($\lambda=$'+str(lambdavar)+')')
plt.legend()
plt.savefig('Convergence_'+str(lambdavar)+'_noreg.pdf')

#with regularisation risque Underfitting

lambdavar_r=0.0005

model_reg = Logistic_Reg_model(input_size)

print('Run training - with reg')
Lists_Results=W2Rcore.W2R_fit(model_reg,X_bw_train,Titles_train, Gen_train, lambdavar_r, EPOCHS = EPOCHS_in, BATCH_SIZE = BATCH_SIZE_in,obs_for_histo=50,DistBetween='All_predictions',DEVICE=DEVICE)

plt.figure()
plt.plot(Lists_Results['Acc'],'g--',label='Error rate')
#plt.plot(lambdavar*np.array(Lists_Results['W2']),'r-',label='$\lambda$*W2')
plt.xlabel('Iterations ($\lambda=$'+str(lambdavar_r)+')')
plt.legend()
plt.savefig('Convergence_'+str(lambdavar_r)+'_reg.pdf')
# Out:
# Run training - without reg
# epoch 0 -- batchNb 1: 0.25357324 0.0 --  lambda=0.0
# epoch 0 -- batchNb 2: 0.24833816 0.0 --  lambda=0.0
# epoch 0 -- batchNb 3: 0.23759066 0.0 --  lambda=0.0
# epoch 0 -- batchNb 4: 0.23843208 0.0 --  lambda=0.0
# epoch 0 -- batchNb 5: 0.2265817 0.0 --  lambda=0.0
# epoch 0 -- batchNb 6: 0.23372212 0.0 --  lambda=0.0
# epoch 0 -- batchNb 7: 0.21675013 0.0 --  lambda=0.0
# epoch 0 -- batchNb 8: 0.21449308 0.0 --  lambda=0.0
# epoch 0 -- batchNb 9: 0.2129648 0.0 --  lambda=0.0
# epoch 0 -- batchNb 10: 0.20990497 0.0 --  lambda=0.0
# epoch 0 -- batchNb 11: 0.20829855 0.0 --  lambda=0.0
# epoch 0 -- batchNb 12: 0.20491388 0.0 --  lambda=0.0
# epoch 0 -- batchNb 13: 0.19570549 0.0 --  lambda=0.0
# epoch 0 -- batchNb 14: 0.18996087 0.0 --  lambda=0.0
# epoch 0 -- batchNb 15: 0.19164644 0.0 --  lambda=0.0
# epoch 0 -- batchNb 16: 0.1920409 0.0 --  lambda=0.0
# epoch 0 -- batchNb 17: 0.18841395 0.0 --  lambda=0.0
# epoch 0 -- batchNb 18: 0.17535965 0.0 --  lambda=0.0
# epoch 0 -- batchNb 19: 0.18416542 0.0 --  lambda=0.0
# epoch 0 -- batchNb 20: 0.17711067 0.0 --  lambda=0.0
# epoch 0 -- batchNb 21: 0.17835493 0.0 --  lambda=0.0
# epoch 0 -- batchNb 22: 0.17204876 0.0 --  lambda=0.0
# epoch 0 -- batchNb 23: 0.1728049 0.0 --  lambda=0.0
# epoch 0 -- batchNb 24: 0.1691607 0.0 --  lambda=0.0
# epoch 0 -- batchNb 25: 0.16399662 0.0 --  lambda=0.0
# epoch 0 -- batchNb 26: 0.16704655 0.0 --  lambda=0.0
# epoch 0 -- batchNb 27: 0.15017773 0.0 --  lambda=0.0
# epoch 0 -- batchNb 28: 0.16048717 0.0 --  lambda=0.0
# epoch 0 -- batchNb 29: 0.15721855 0.0 --  lambda=0.0
# epoch 0 -- batchNb 30: 0.14882158 0.0 --  lambda=0.0
# epoch 0 -- batchNb 31: 0.14810312 0.0 --  lambda=0.0
# epoch 0 -- batchNb 32: 0.14917356 0.0 --  lambda=0.0
# epoch 0 -- batchNb 33: 0.14569753 0.0 --  lambda=0.0
# epoch 0 -- batchNb 34: 0.14546251 0.0 --  lambda=0.0
# epoch 0 -- batchNb 35: 0.1552775 0.0 --  lambda=0.0
# epoch 0 -- batchNb 36: 0.15346758 0.0 --  lambda=0.0
# epoch 0 -- batchNb 37: 0.12739302 0.0 --  lambda=0.0
# epoch 0 -- batchNb 38: 0.13231967 0.0 --  lambda=0.0
# epoch 0 -- batchNb 39: 0.13252716 0.0 --  lambda=0.0
# epoch 0 -- batchNb 40: 0.13371879 0.0 --  lambda=0.0
# epoch 0 -- batchNb 41: 0.1348716 0.0 --  lambda=0.0
# epoch 0 -- batchNb 42: 0.12657171 0.0 --  lambda=0.0
# epoch 0 -- batchNb 43: 0.13113084 0.0 --  lambda=0.0
# epoch 0 -- batchNb 44: 0.13542919 0.0 --  lambda=0.0
# epoch 0 -- batchNb 45: 0.13629393 0.0 --  lambda=0.0
# epoch 0 -- batchNb 46: 0.13475397 0.0 --  lambda=0.0
# epoch 0 -- batchNb 47: 0.12770696 0.0 --  lambda=0.0
# epoch 0 -- batchNb 48: 0.12457893 0.0 --  lambda=0.0
# epoch 0 -- batchNb 49: 0.124485075 0.0 --  lambda=0.0
# epoch 0 -- batchNb 50: 0.12269331 0.0 --  lambda=0.0
# epoch 0 -- batchNb 51: 0.12447491 0.0 --  lambda=0.0
# epoch 0 -- batchNb 52: 0.118676454 0.0 --  lambda=0.0
# epoch 0 -- batchNb 53: 0.12325051 0.0 --  lambda=0.0
# epoch 0 -- batchNb 54: 0.117829084 0.0 --  lambda=0.0
# epoch 0 -- batchNb 55: 0.11585657 0.0 --  lambda=0.0
# epoch 0 -- batchNb 56: 0.12744194 0.0 --  lambda=0.0
# epoch 0 -- batchNb 57: 0.11269088 0.0 --  lambda=0.0
# epoch 0 -- batchNb 58: 0.11848134 0.0 --  lambda=0.0
# epoch 0 -- batchNb 59: 0.12730682 0.0 --  lambda=0.0
# epoch 0 -- batchNb 60: 0.11561626 0.0 --  lambda=0.0
# epoch 0 -- batchNb 61: 0.11333865 0.0 --  lambda=0.0
# epoch 0 -- batchNb 62: 0.1208435 0.0 --  lambda=0.0
# epoch 0 -- batchNb 63: 0.11195707 0.0 --  lambda=0.0
# epoch 0 -- batchNb 64: 0.11988939 0.0 --  lambda=0.0
# epoch 0 -- batchNb 65: 0.11762231 0.0 --  lambda=0.0
# epoch 0 -- batchNb 66: 0.110207826 0.0 --  lambda=0.0
# epoch 0 -- batchNb 67: 0.12017149 0.0 --  lambda=0.0
# epoch 0 -- batchNb 68: 0.10779441 0.0 --  lambda=0.0
# epoch 0 -- batchNb 69: 0.101361185 0.0 --  lambda=0.0
# epoch 0 -- batchNb 70: 0.111520335 0.0 --  lambda=0.0
# epoch 0 -- batchNb 71: 0.10437411 0.0 --  lambda=0.0
# epoch 0 -- batchNb 72: 0.09900574 0.0 --  lambda=0.0
# epoch 0 -- batchNb 73: 0.10566203 0.0 --  lambda=0.0
# epoch 0 -- batchNb 74: 0.10315668 0.0 --  lambda=0.0
# epoch 0 -- batchNb 75: 0.1045188 0.0 --  lambda=0.0
# epoch 0 -- batchNb 76: 0.10436715 0.0 --  lambda=0.0
# epoch 0 -- batchNb 77: 0.11330202 0.0 --  lambda=0.0
# epoch 0 -- batchNb 78: 0.09365442 0.0 --  lambda=0.0
# epoch 0 -- batchNb 79: 0.09543321 0.0 --  lambda=0.0
# epoch 0 -- batchNb 80: 0.10730855 0.0 --  lambda=0.0
# epoch 0 -- batchNb 81: 0.10549244 0.0 --  lambda=0.0
# epoch 0 -- batchNb 82: 0.11069703 0.0 --  lambda=0.0
# epoch 0 -- batchNb 83: 0.10080762 0.0 --  lambda=0.0
# epoch 0 -- batchNb 84: 0.11127886 0.0 --  lambda=0.0
# epoch 0 -- batchNb 85: 0.095432796 0.0 --  lambda=0.0
# epoch 0 -- batchNb 86: 0.10329214 0.0 --  lambda=0.0
# epoch 0 -- batchNb 87: 0.08229023 0.0 --  lambda=0.0
# epoch 0 -- batchNb 88: 0.09918333 0.0 --  lambda=0.0
# epoch 0 -- batchNb 89: 0.088635534 0.0 --  lambda=0.0
# epoch 0 -- batchNb 90: 0.095000304 0.0 --  lambda=0.0
# epoch 0 -- batchNb 91: 0.0950507 0.0 --  lambda=0.0
# epoch 0 -- batchNb 92: 0.09225119 0.0 --  lambda=0.0
# epoch 0 -- batchNb 93: 0.10842553 0.0 --  lambda=0.0
# epoch 0 -- batchNb 94: 0.107316434 0.0 --  lambda=0.0
# epoch 0 -- batchNb 95: 0.09785927 0.0 --  lambda=0.0
# epoch 0 -- batchNb 96: 0.098343246 0.0 --  lambda=0.0
# epoch 1 -- batchNb 1: 0.098719575 0.0 --  lambda=0.0
# epoch 1 -- batchNb 2: 0.10068293 0.0 --  lambda=0.0
# epoch 1 -- batchNb 3: 0.0878955 0.0 --  lambda=0.0
# epoch 1 -- batchNb 4: 0.09210092 0.0 --  lambda=0.0
# epoch 1 -- batchNb 5: 0.099497765 0.0 --  lambda=0.0
# epoch 1 -- batchNb 6: 0.07872342 0.0 --  lambda=0.0
# epoch 1 -- batchNb 7: 0.09029022 0.0 --  lambda=0.0
# epoch 1 -- batchNb 8: 0.08386434 0.0 --  lambda=0.0
# epoch 1 -- batchNb 9: 0.08852519 0.0 --  lambda=0.0
# epoch 1 -- batchNb 10: 0.09387038 0.0 --  lambda=0.0
# epoch 1 -- batchNb 11: 0.091493234 0.0 --  lambda=0.0
# epoch 1 -- batchNb 12: 0.09001734 0.0 --  lambda=0.0
# epoch 1 -- batchNb 13: 0.07867783 0.0 --  lambda=0.0
# epoch 1 -- batchNb 14: 0.10533579 0.0 --  lambda=0.0
# epoch 1 -- batchNb 15: 0.08607136 0.0 --  lambda=0.0
# epoch 1 -- batchNb 16: 0.08829342 0.0 --  lambda=0.0
# epoch 1 -- batchNb 17: 0.08517107 0.0 --  lambda=0.0
# epoch 1 -- batchNb 18: 0.0967147 0.0 --  lambda=0.0
# epoch 1 -- batchNb 19: 0.0966251 0.0 --  lambda=0.0
# epoch 1 -- batchNb 20: 0.09073943 0.0 --  lambda=0.0
# epoch 1 -- batchNb 21: 0.09250618 0.0 --  lambda=0.0
# epoch 1 -- batchNb 22: 0.09123388 0.0 --  lambda=0.0
# epoch 1 -- batchNb 23: 0.08373032 0.0 --  lambda=0.0
# epoch 1 -- batchNb 24: 0.091424234 0.0 --  lambda=0.0
# epoch 1 -- batchNb 25: 0.07790985 0.0 --  lambda=0.0
# epoch 1 -- batchNb 26: 0.07735858 0.0 --  lambda=0.0
# epoch 1 -- batchNb 27: 0.082360156 0.0 --  lambda=0.0
# epoch 1 -- batchNb 28: 0.101631254 0.0 --  lambda=0.0
# epoch 1 -- batchNb 29: 0.080861814 0.0 --  lambda=0.0
# epoch 1 -- batchNb 30: 0.07416704 0.0 --  lambda=0.0
# epoch 1 -- batchNb 31: 0.07540043 0.0 --  lambda=0.0
# epoch 1 -- batchNb 32: 0.07082688 0.0 --  lambda=0.0
# epoch 1 -- batchNb 33: 0.08867396 0.0 --  lambda=0.0
# epoch 1 -- batchNb 34: 0.08153029 0.0 --  lambda=0.0
# epoch 1 -- batchNb 35: 0.0918431 0.0 --  lambda=0.0
# epoch 1 -- batchNb 36: 0.067308836 0.0 --  lambda=0.0
# epoch 1 -- batchNb 37: 0.092009 0.0 --  lambda=0.0
# epoch 1 -- batchNb 38: 0.08892525 0.0 --  lambda=0.0
# epoch 1 -- batchNb 39: 0.07380959 0.0 --  lambda=0.0
# epoch 1 -- batchNb 40: 0.06613748 0.0 --  lambda=0.0
# epoch 1 -- batchNb 41: 0.090380095 0.0 --  lambda=0.0
# epoch 1 -- batchNb 42: 0.08916674 0.0 --  lambda=0.0
# epoch 1 -- batchNb 43: 0.086521775 0.0 --  lambda=0.0
# epoch 1 -- batchNb 44: 0.0880835 0.0 --  lambda=0.0
# epoch 1 -- batchNb 45: 0.08553117 0.0 --  lambda=0.0
# epoch 1 -- batchNb 46: 0.09110744 0.0 --  lambda=0.0
# epoch 1 -- batchNb 47: 0.08059668 0.0 --  lambda=0.0
# epoch 1 -- batchNb 48: 0.06802991 0.0 --  lambda=0.0
# epoch 1 -- batchNb 49: 0.07426453 0.0 --  lambda=0.0
# epoch 1 -- batchNb 50: 0.08203833 0.0 --  lambda=0.0
# epoch 1 -- batchNb 51: 0.07062806 0.0 --  lambda=0.0
# epoch 1 -- batchNb 52: 0.08678183 0.0 --  lambda=0.0
# epoch 1 -- batchNb 53: 0.07764142 0.0 --  lambda=0.0
# epoch 1 -- batchNb 54: 0.07464956 0.0 --  lambda=0.0
# epoch 1 -- batchNb 55: 0.081161134 0.0 --  lambda=0.0
# epoch 1 -- batchNb 56: 0.07960756 0.0 --  lambda=0.0
# epoch 1 -- batchNb 57: 0.08247266 0.0 --  lambda=0.0
# epoch 1 -- batchNb 58: 0.06576719 0.0 --  lambda=0.0
# epoch 1 -- batchNb 59: 0.073251195 0.0 --  lambda=0.0
# epoch 1 -- batchNb 60: 0.07724555 0.0 --  lambda=0.0
# epoch 1 -- batchNb 61: 0.08716352 0.0 --  lambda=0.0
# epoch 1 -- batchNb 62: 0.09089932 0.0 --  lambda=0.0
# epoch 1 -- batchNb 63: 0.07970547 0.0 --  lambda=0.0
# epoch 1 -- batchNb 64: 0.07881872 0.0 --  lambda=0.0
# epoch 1 -- batchNb 65: 0.07991001 0.0 --  lambda=0.0
# epoch 1 -- batchNb 66: 0.06944229 0.0 --  lambda=0.0
# epoch 1 -- batchNb 67: 0.076494336 0.0 --  lambda=0.0
# epoch 1 -- batchNb 68: 0.0742247 0.0 --  lambda=0.0
# epoch 1 -- batchNb 69: 0.0880344 0.0 --  lambda=0.0
# epoch 1 -- batchNb 70: 0.08260048 0.0 --  lambda=0.0
# epoch 1 -- batchNb 71: 0.0782754 0.0 --  lambda=0.0
# epoch 1 -- batchNb 72: 0.07526806 0.0 --  lambda=0.0
# epoch 1 -- batchNb 73: 0.07330638 0.0 --  lambda=0.0
# epoch 1 -- batchNb 74: 0.07287285 0.0 --  lambda=0.0
# epoch 1 -- batchNb 75: 0.07042108 0.0 --  lambda=0.0
# epoch 1 -- batchNb 76: 0.07569821 0.0 --  lambda=0.0
# epoch 1 -- batchNb 77: 0.08417561 0.0 --  lambda=0.0
# epoch 1 -- batchNb 78: 0.05906837 0.0 --  lambda=0.0
# epoch 1 -- batchNb 79: 0.07605454 0.0 --  lambda=0.0
# epoch 1 -- batchNb 80: 0.07811364 0.0 --  lambda=0.0
# epoch 1 -- batchNb 81: 0.07635667 0.0 --  lambda=0.0
# epoch 1 -- batchNb 82: 0.06668849 0.0 --  lambda=0.0
# epoch 1 -- batchNb 83: 0.08010914 0.0 --  lambda=0.0
# epoch 1 -- batchNb 84: 0.07389478 0.0 --  lambda=0.0
# epoch 1 -- batchNb 85: 0.065479115 0.0 --  lambda=0.0
# epoch 1 -- batchNb 86: 0.057792965 0.0 --  lambda=0.0
# epoch 1 -- batchNb 87: 0.07182369 0.0 --  lambda=0.0
# epoch 1 -- batchNb 88: 0.06850962 0.0 --  lambda=0.0
# epoch 1 -- batchNb 89: 0.062972955 0.0 --  lambda=0.0
# epoch 1 -- batchNb 90: 0.06707729 0.0 --  lambda=0.0
# epoch 1 -- batchNb 91: 0.0749089 0.0 --  lambda=0.0
# epoch 1 -- batchNb 92: 0.06764031 0.0 --  lambda=0.0
# epoch 1 -- batchNb 93: 0.077670276 0.0 --  lambda=0.0
# epoch 1 -- batchNb 94: 0.07064393 0.0 --  lambda=0.0
# epoch 1 -- batchNb 95: 0.0697637 0.0 --  lambda=0.0
# epoch 1 -- batchNb 96: 0.065466836 0.0 --  lambda=0.0
# epoch 2 -- batchNb 1: 0.07735446 0.0 --  lambda=0.0
# epoch 2 -- batchNb 2: 0.066333525 0.0 --  lambda=0.0
# epoch 2 -- batchNb 3: 0.07241732 0.0 --  lambda=0.0
# epoch 2 -- batchNb 4: 0.06638876 0.0 --  lambda=0.0
# epoch 2 -- batchNb 5: 0.076359004 0.0 --  lambda=0.0
# epoch 2 -- batchNb 6: 0.06432481 0.0 --  lambda=0.0
# epoch 2 -- batchNb 7: 0.06401495 0.0 --  lambda=0.0
# epoch 2 -- batchNb 8: 0.06190441 0.0 --  lambda=0.0
# epoch 2 -- batchNb 9: 0.06969526 0.0 --  lambda=0.0
# epoch 2 -- batchNb 10: 0.06879946 0.0 --  lambda=0.0
# epoch 2 -- batchNb 11: 0.07695569 0.0 --  lambda=0.0
# epoch 2 -- batchNb 12: 0.07972469 0.0 --  lambda=0.0
# epoch 2 -- batchNb 13: 0.07102331 0.0 --  lambda=0.0
# epoch 2 -- batchNb 14: 0.077297665 0.0 --  lambda=0.0
# epoch 2 -- batchNb 15: 0.07400294 0.0 --  lambda=0.0
# epoch 2 -- batchNb 16: 0.06834832 0.0 --  lambda=0.0
# epoch 2 -- batchNb 17: 0.06447267 0.0 --  lambda=0.0
# epoch 2 -- batchNb 18: 0.07675512 0.0 --  lambda=0.0
# epoch 2 -- batchNb 19: 0.06608992 0.0 --  lambda=0.0
# epoch 2 -- batchNb 20: 0.06350142 0.0 --  lambda=0.0
# epoch 2 -- batchNb 21: 0.062245317 0.0 --  lambda=0.0
# epoch 2 -- batchNb 22: 0.05831545 0.0 --  lambda=0.0
# epoch 2 -- batchNb 23: 0.07199827 0.0 --  lambda=0.0
# epoch 2 -- batchNb 24: 0.058325816 0.0 --  lambda=0.0
# epoch 2 -- batchNb 25: 0.06766545 0.0 --  lambda=0.0
# epoch 2 -- batchNb 26: 0.052775636 0.0 --  lambda=0.0
# epoch 2 -- batchNb 27: 0.06062369 0.0 --  lambda=0.0
# epoch 2 -- batchNb 28: 0.05710042 0.0 --  lambda=0.0
# epoch 2 -- batchNb 29: 0.070767924 0.0 --  lambda=0.0
# epoch 2 -- batchNb 30: 0.080271624 0.0 --  lambda=0.0
# epoch 2 -- batchNb 31: 0.071956344 0.0 --  lambda=0.0
# epoch 2 -- batchNb 32: 0.070052214 0.0 --  lambda=0.0
# epoch 2 -- batchNb 33: 0.059700947 0.0 --  lambda=0.0
# epoch 2 -- batchNb 34: 0.0689952 0.0 --  lambda=0.0
# epoch 2 -- batchNb 35: 0.07081139 0.0 --  lambda=0.0
# epoch 2 -- batchNb 36: 0.070690304 0.0 --  lambda=0.0
# epoch 2 -- batchNb 37: 0.061386183 0.0 --  lambda=0.0
# epoch 2 -- batchNb 38: 0.06828706 0.0 --  lambda=0.0
# epoch 2 -- batchNb 39: 0.065224834 0.0 --  lambda=0.0
# epoch 2 -- batchNb 40: 0.06842702 0.0 --  lambda=0.0
# epoch 2 -- batchNb 41: 0.06409645 0.0 --  lambda=0.0
# epoch 2 -- batchNb 42: 0.07312169 0.0 --  lambda=0.0
# epoch 2 -- batchNb 43: 0.06392669 0.0 --  lambda=0.0
# epoch 2 -- batchNb 44: 0.06970229 0.0 --  lambda=0.0
# epoch 2 -- batchNb 45: 0.07556327 0.0 --  lambda=0.0
# epoch 2 -- batchNb 46: 0.05981765 0.0 --  lambda=0.0
# epoch 2 -- batchNb 47: 0.073527195 0.0 --  lambda=0.0
# epoch 2 -- batchNb 48: 0.062361937 0.0 --  lambda=0.0
# epoch 2 -- batchNb 49: 0.059816003 0.0 --  lambda=0.0
# epoch 2 -- batchNb 50: 0.05910261 0.0 --  lambda=0.0
# epoch 2 -- batchNb 51: 0.061850775 0.0 --  lambda=0.0
# epoch 2 -- batchNb 52: 0.06587644 0.0 --  lambda=0.0
# epoch 2 -- batchNb 53: 0.06042763 0.0 --  lambda=0.0
# epoch 2 -- batchNb 54: 0.07020686 0.0 --  lambda=0.0
# epoch 2 -- batchNb 55: 0.064695776 0.0 --  lambda=0.0
# epoch 2 -- batchNb 56: 0.05567927 0.0 --  lambda=0.0
# epoch 2 -- batchNb 57: 0.070549324 0.0 --  lambda=0.0
# epoch 2 -- batchNb 58: 0.067366414 0.0 --  lambda=0.0
# epoch 2 -- batchNb 59: 0.062525816 0.0 --  lambda=0.0
# epoch 2 -- batchNb 60: 0.056446176 0.0 --  lambda=0.0
# epoch 2 -- batchNb 61: 0.061868496 0.0 --  lambda=0.0
# epoch 2 -- batchNb 62: 0.05977588 0.0 --  lambda=0.0
# epoch 2 -- batchNb 63: 0.049014818 0.0 --  lambda=0.0
# epoch 2 -- batchNb 64: 0.072161324 0.0 --  lambda=0.0
# epoch 2 -- batchNb 65: 0.06973293 0.0 --  lambda=0.0
# epoch 2 -- batchNb 66: 0.06084844 0.0 --  lambda=0.0
# epoch 2 -- batchNb 67: 0.067021914 0.0 --  lambda=0.0
# epoch 2 -- batchNb 68: 0.05271998 0.0 --  lambda=0.0
# epoch 2 -- batchNb 69: 0.056220986 0.0 --  lambda=0.0
# epoch 2 -- batchNb 70: 0.07570467 0.0 --  lambda=0.0
# epoch 2 -- batchNb 71: 0.0639041 0.0 --  lambda=0.0
# epoch 2 -- batchNb 72: 0.060962405 0.0 --  lambda=0.0
# epoch 2 -- batchNb 73: 0.052013647 0.0 --  lambda=0.0
# epoch 2 -- batchNb 74: 0.07594239 0.0 --  lambda=0.0
# epoch 2 -- batchNb 75: 0.05742939 0.0 --  lambda=0.0
# epoch 2 -- batchNb 76: 0.060693197 0.0 --  lambda=0.0
# epoch 2 -- batchNb 77: 0.062267527 0.0 --  lambda=0.0
# epoch 2 -- batchNb 78: 0.07423029 0.0 --  lambda=0.0
# epoch 2 -- batchNb 79: 0.06572622 0.0 --  lambda=0.0
# epoch 2 -- batchNb 80: 0.0684453 0.0 --  lambda=0.0
# epoch 2 -- batchNb 81: 0.088772126 0.0 --  lambda=0.0
# epoch 2 -- batchNb 82: 0.06472134 0.0 --  lambda=0.0
# epoch 2 -- batchNb 83: 0.051667467 0.0 --  lambda=0.0
# epoch 2 -- batchNb 84: 0.0526012 0.0 --  lambda=0.0
# epoch 2 -- batchNb 85: 0.062125865 0.0 --  lambda=0.0
# epoch 2 -- batchNb 86: 0.057662673 0.0 --  lambda=0.0
# epoch 2 -- batchNb 87: 0.0706042 0.0 --  lambda=0.0
# epoch 2 -- batchNb 88: 0.065379456 0.0 --  lambda=0.0
# epoch 2 -- batchNb 89: 0.06490622 0.0 --  lambda=0.0
# epoch 2 -- batchNb 90: 0.068418205 0.0 --  lambda=0.0
# epoch 2 -- batchNb 91: 0.053586178 0.0 --  lambda=0.0
# epoch 2 -- batchNb 92: 0.050105132 0.0 --  lambda=0.0
# epoch 2 -- batchNb 93: 0.05178614 0.0 --  lambda=0.0
# epoch 2 -- batchNb 94: 0.0703587 0.0 --  lambda=0.0
# epoch 2 -- batchNb 95: 0.06363047 0.0 --  lambda=0.0
# epoch 2 -- batchNb 96: 0.06973874 0.0 --  lambda=0.0
# epoch 3 -- batchNb 1: 0.059452377 0.0 --  lambda=0.0
# epoch 3 -- batchNb 2: 0.057705555 0.0 --  lambda=0.0
# epoch 3 -- batchNb 3: 0.062458772 0.0 --  lambda=0.0
# epoch 3 -- batchNb 4: 0.05529331 0.0 --  lambda=0.0
# epoch 3 -- batchNb 5: 0.06462517 0.0 --  lambda=0.0
# epoch 3 -- batchNb 6: 0.058885336 0.0 --  lambda=0.0
# epoch 3 -- batchNb 7: 0.052967776 0.0 --  lambda=0.0
# epoch 3 -- batchNb 8: 0.05122624 0.0 --  lambda=0.0
# epoch 3 -- batchNb 9: 0.059233002 0.0 --  lambda=0.0
# epoch 3 -- batchNb 10: 0.073843375 0.0 --  lambda=0.0
# epoch 3 -- batchNb 11: 0.054357115 0.0 --  lambda=0.0
# epoch 3 -- batchNb 12: 0.06748789 0.0 --  lambda=0.0
# epoch 3 -- batchNb 13: 0.056941863 0.0 --  lambda=0.0
# epoch 3 -- batchNb 14: 0.06552898 0.0 --  lambda=0.0
# epoch 3 -- batchNb 15: 0.05194572 0.0 --  lambda=0.0
# epoch 3 -- batchNb 16: 0.0565335 0.0 --  lambda=0.0
# epoch 3 -- batchNb 17: 0.05587082 0.0 --  lambda=0.0
# epoch 3 -- batchNb 18: 0.07377504 0.0 --  lambda=0.0
# epoch 3 -- batchNb 19: 0.06405921 0.0 --  lambda=0.0
# epoch 3 -- batchNb 20: 0.061064176 0.0 --  lambda=0.0
# epoch 3 -- batchNb 21: 0.057764366 0.0 --  lambda=0.0
# epoch 3 -- batchNb 22: 0.06488859 0.0 --  lambda=0.0
# epoch 3 -- batchNb 23: 0.050962213 0.0 --  lambda=0.0
# epoch 3 -- batchNb 24: 0.06230581 0.0 --  lambda=0.0
# epoch 3 -- batchNb 25: 0.058981232 0.0 --  lambda=0.0
# epoch 3 -- batchNb 26: 0.061039954 0.0 --  lambda=0.0
# epoch 3 -- batchNb 27: 0.052019805 0.0 --  lambda=0.0
# epoch 3 -- batchNb 28: 0.062080845 0.0 --  lambda=0.0
# epoch 3 -- batchNb 29: 0.053929683 0.0 --  lambda=0.0
# epoch 3 -- batchNb 30: 0.05470763 0.0 --  lambda=0.0
# epoch 3 -- batchNb 31: 0.060749568 0.0 --  lambda=0.0
# epoch 3 -- batchNb 32: 0.071291916 0.0 --  lambda=0.0
# epoch 3 -- batchNb 33: 0.06615396 0.0 --  lambda=0.0
# epoch 3 -- batchNb 34: 0.05812505 0.0 --  lambda=0.0
# epoch 3 -- batchNb 35: 0.048433684 0.0 --  lambda=0.0
# epoch 3 -- batchNb 36: 0.04749199 0.0 --  lambda=0.0
# epoch 3 -- batchNb 37: 0.051770564 0.0 --  lambda=0.0
# epoch 3 -- batchNb 38: 0.058703836 0.0 --  lambda=0.0
# epoch 3 -- batchNb 39: 0.071105585 0.0 --  lambda=0.0
# epoch 3 -- batchNb 40: 0.050694462 0.0 --  lambda=0.0
# epoch 3 -- batchNb 41: 0.060204603 0.0 --  lambda=0.0
# epoch 3 -- batchNb 42: 0.06154341 0.0 --  lambda=0.0
# epoch 3 -- batchNb 43: 0.05364328 0.0 --  lambda=0.0
# epoch 3 -- batchNb 44: 0.061490435 0.0 --  lambda=0.0
# epoch 3 -- batchNb 45: 0.073836386 0.0 --  lambda=0.0
# epoch 3 -- batchNb 46: 0.048818413 0.0 --  lambda=0.0
# epoch 3 -- batchNb 47: 0.05112413 0.0 --  lambda=0.0
# epoch 3 -- batchNb 48: 0.059931573 0.0 --  lambda=0.0
# epoch 3 -- batchNb 49: 0.063127354 0.0 --  lambda=0.0
# epoch 3 -- batchNb 50: 0.06250584 0.0 --  lambda=0.0
# epoch 3 -- batchNb 51: 0.053618737 0.0 --  lambda=0.0
# epoch 3 -- batchNb 52: 0.0590267 0.0 --  lambda=0.0
# epoch 3 -- batchNb 53: 0.07536076 0.0 --  lambda=0.0
# epoch 3 -- batchNb 54: 0.05153471 0.0 --  lambda=0.0
# epoch 3 -- batchNb 55: 0.05607641 0.0 --  lambda=0.0
# epoch 3 -- batchNb 56: 0.058195792 0.0 --  lambda=0.0
# epoch 3 -- batchNb 57: 0.05048212 0.0 --  lambda=0.0
# epoch 3 -- batchNb 58: 0.056012467 0.0 --  lambda=0.0
# epoch 3 -- batchNb 59: 0.05654168 0.0 --  lambda=0.0
# epoch 3 -- batchNb 60: 0.064341076 0.0 --  lambda=0.0
# epoch 3 -- batchNb 61: 0.060642444 0.0 --  lambda=0.0
# epoch 3 -- batchNb 62: 0.044059638 0.0 --  lambda=0.0
# epoch 3 -- batchNb 63: 0.054041866 0.0 --  lambda=0.0
# epoch 3 -- batchNb 64: 0.05659045 0.0 --  lambda=0.0
# epoch 3 -- batchNb 65: 0.051469877 0.0 --  lambda=0.0
# epoch 3 -- batchNb 66: 0.05341242 0.0 --  lambda=0.0
# epoch 3 -- batchNb 67: 0.05653846 0.0 --  lambda=0.0
# epoch 3 -- batchNb 68: 0.057348933 0.0 --  lambda=0.0
# epoch 3 -- batchNb 69: 0.057038497 0.0 --  lambda=0.0
# epoch 3 -- batchNb 70: 0.05898467 0.0 --  lambda=0.0
# epoch 3 -- batchNb 71: 0.05883403 0.0 --  lambda=0.0
# epoch 3 -- batchNb 72: 0.052430972 0.0 --  lambda=0.0
# epoch 3 -- batchNb 73: 0.054787125 0.0 --  lambda=0.0
# epoch 3 -- batchNb 74: 0.045912366 0.0 --  lambda=0.0
# epoch 3 -- batchNb 75: 0.064563066 0.0 --  lambda=0.0
# epoch 3 -- batchNb 76: 0.050465647 0.0 --  lambda=0.0
# epoch 3 -- batchNb 77: 0.05488884 0.0 --  lambda=0.0
# epoch 3 -- batchNb 78: 0.05063604 0.0 --  lambda=0.0
# epoch 3 -- batchNb 79: 0.052076742 0.0 --  lambda=0.0
# epoch 3 -- batchNb 80: 0.056074042 0.0 --  lambda=0.0
# epoch 3 -- batchNb 81: 0.05833461 0.0 --  lambda=0.0
# epoch 3 -- batchNb 82: 0.043890286 0.0 --  lambda=0.0
# epoch 3 -- batchNb 83: 0.060782786 0.0 --  lambda=0.0
# epoch 3 -- batchNb 84: 0.05853375 0.0 --  lambda=0.0
# epoch 3 -- batchNb 85: 0.059653845 0.0 --  lambda=0.0
# epoch 3 -- batchNb 86: 0.063692294 0.0 --  lambda=0.0
# epoch 3 -- batchNb 87: 0.054868415 0.0 --  lambda=0.0
# epoch 3 -- batchNb 88: 0.049570903 0.0 --  lambda=0.0
# epoch 3 -- batchNb 89: 0.06505466 0.0 --  lambda=0.0
# epoch 3 -- batchNb 90: 0.047798112 0.0 --  lambda=0.0
# epoch 3 -- batchNb 91: 0.054188445 0.0 --  lambda=0.0
# epoch 3 -- batchNb 92: 0.056588 0.0 --  lambda=0.0
# epoch 3 -- batchNb 93: 0.048884913 0.0 --  lambda=0.0
# epoch 3 -- batchNb 94: 0.05732995 0.0 --  lambda=0.0
# epoch 3 -- batchNb 95: 0.059654955 0.0 --  lambda=0.0
# epoch 3 -- batchNb 96: 0.050845552 0.0 --  lambda=0.0
# epoch 4 -- batchNb 1: 0.053919148 0.0 --  lambda=0.0
# epoch 4 -- batchNb 2: 0.05449832 0.0 --  lambda=0.0
# epoch 4 -- batchNb 3: 0.053449683 0.0 --  lambda=0.0
# epoch 4 -- batchNb 4: 0.04875347 0.0 --  lambda=0.0
# epoch 4 -- batchNb 5: 0.051443804 0.0 --  lambda=0.0
# epoch 4 -- batchNb 6: 0.052634053 0.0 --  lambda=0.0
# epoch 4 -- batchNb 7: 0.04925032 0.0 --  lambda=0.0
# epoch 4 -- batchNb 8: 0.050821047 0.0 --  lambda=0.0
# epoch 4 -- batchNb 9: 0.04212684 0.0 --  lambda=0.0
# epoch 4 -- batchNb 10: 0.043637775 0.0 --  lambda=0.0
# epoch 4 -- batchNb 11: 0.07082729 0.0 --  lambda=0.0
# epoch 4 -- batchNb 12: 0.05488425 0.0 --  lambda=0.0
# epoch 4 -- batchNb 13: 0.060599595 0.0 --  lambda=0.0
# epoch 4 -- batchNb 14: 0.06919004 0.0 --  lambda=0.0
# epoch 4 -- batchNb 15: 0.043422543 0.0 --  lambda=0.0
# epoch 4 -- batchNb 16: 0.044571992 0.0 --  lambda=0.0
# epoch 4 -- batchNb 17: 0.07604987 0.0 --  lambda=0.0
# epoch 4 -- batchNb 18: 0.047322813 0.0 --  lambda=0.0
# epoch 4 -- batchNb 19: 0.046354007 0.0 --  lambda=0.0
# epoch 4 -- batchNb 20: 0.053405665 0.0 --  lambda=0.0
# epoch 4 -- batchNb 21: 0.063615344 0.0 --  lambda=0.0
# epoch 4 -- batchNb 22: 0.054586373 0.0 --  lambda=0.0
# epoch 4 -- batchNb 23: 0.056063943 0.0 --  lambda=0.0
# epoch 4 -- batchNb 24: 0.05192916 0.0 --  lambda=0.0
# epoch 4 -- batchNb 25: 0.054265436 0.0 --  lambda=0.0
# epoch 4 -- batchNb 26: 0.0408439 0.0 --  lambda=0.0
# epoch 4 -- batchNb 27: 0.043612078 0.0 --  lambda=0.0
# epoch 4 -- batchNb 28: 0.049176298 0.0 --  lambda=0.0
# epoch 4 -- batchNb 29: 0.06680284 0.0 --  lambda=0.0
# epoch 4 -- batchNb 30: 0.04569767 0.0 --  lambda=0.0
# epoch 4 -- batchNb 31: 0.049028035 0.0 --  lambda=0.0
# epoch 4 -- batchNb 32: 0.058305312 0.0 --  lambda=0.0
# epoch 4 -- batchNb 33: 0.05874413 0.0 --  lambda=0.0
# epoch 4 -- batchNb 34: 0.05889899 0.0 --  lambda=0.0
# epoch 4 -- batchNb 35: 0.057405397 0.0 --  lambda=0.0
# epoch 4 -- batchNb 36: 0.050270353 0.0 --  lambda=0.0
# epoch 4 -- batchNb 37: 0.04761563 0.0 --  lambda=0.0
# epoch 4 -- batchNb 38: 0.04996312 0.0 --  lambda=0.0
# epoch 4 -- batchNb 39: 0.058994 0.0 --  lambda=0.0
# epoch 4 -- batchNb 40: 0.058514167 0.0 --  lambda=0.0
# epoch 4 -- batchNb 41: 0.046462703 0.0 --  lambda=0.0
# epoch 4 -- batchNb 42: 0.045981325 0.0 --  lambda=0.0
# epoch 4 -- batchNb 43: 0.053419277 0.0 --  lambda=0.0
# epoch 4 -- batchNb 44: 0.0563728 0.0 --  lambda=0.0
# epoch 4 -- batchNb 45: 0.05180137 0.0 --  lambda=0.0
# epoch 4 -- batchNb 46: 0.046835434 0.0 --  lambda=0.0
# epoch 4 -- batchNb 47: 0.04577225 0.0 --  lambda=0.0
# epoch 4 -- batchNb 48: 0.052316524 0.0 --  lambda=0.0
# epoch 4 -- batchNb 49: 0.057212353 0.0 --  lambda=0.0
# epoch 4 -- batchNb 50: 0.056754902 0.0 --  lambda=0.0
# epoch 4 -- batchNb 51: 0.056832198 0.0 --  lambda=0.0
# epoch 4 -- batchNb 52: 0.0539147 0.0 --  lambda=0.0
# epoch 4 -- batchNb 53: 0.051976703 0.0 --  lambda=0.0
# epoch 4 -- batchNb 54: 0.06503421 0.0 --  lambda=0.0
# epoch 4 -- batchNb 55: 0.057773046 0.0 --  lambda=0.0
# epoch 4 -- batchNb 56: 0.04098603 0.0 --  lambda=0.0
# epoch 4 -- batchNb 57: 0.041537806 0.0 --  lambda=0.0
# epoch 4 -- batchNb 58: 0.052331187 0.0 --  lambda=0.0
# epoch 4 -- batchNb 59: 0.03969591 0.0 --  lambda=0.0
# epoch 4 -- batchNb 60: 0.05573154 0.0 --  lambda=0.0
# epoch 4 -- batchNb 61: 0.053469468 0.0 --  lambda=0.0
# epoch 4 -- batchNb 62: 0.059398808 0.0 --  lambda=0.0
# epoch 4 -- batchNb 63: 0.053313885 0.0 --  lambda=0.0
# epoch 4 -- batchNb 64: 0.058808282 0.0 --  lambda=0.0
# epoch 4 -- batchNb 65: 0.05229146 0.0 --  lambda=0.0
# epoch 4 -- batchNb 66: 0.049206372 0.0 --  lambda=0.0
# epoch 4 -- batchNb 67: 0.051206708 0.0 --  lambda=0.0
# epoch 4 -- batchNb 68: 0.054053012 0.0 --  lambda=0.0
# epoch 4 -- batchNb 69: 0.044221386 0.0 --  lambda=0.0
# epoch 4 -- batchNb 70: 0.055095978 0.0 --  lambda=0.0
# epoch 4 -- batchNb 71: 0.053545352 0.0 --  lambda=0.0
# epoch 4 -- batchNb 72: 0.055092953 0.0 --  lambda=0.0
# epoch 4 -- batchNb 73: 0.057268735 0.0 --  lambda=0.0
# epoch 4 -- batchNb 74: 0.051598504 0.0 --  lambda=0.0
# epoch 4 -- batchNb 75: 0.055180036 0.0 --  lambda=0.0
# epoch 4 -- batchNb 76: 0.06157266 0.0 --  lambda=0.0
# epoch 4 -- batchNb 77: 0.057660934 0.0 --  lambda=0.0
# epoch 4 -- batchNb 78: 0.051977195 0.0 --  lambda=0.0
# epoch 4 -- batchNb 79: 0.042419363 0.0 --  lambda=0.0
# epoch 4 -- batchNb 80: 0.044521116 0.0 --  lambda=0.0
# epoch 4 -- batchNb 81: 0.052839573 0.0 --  lambda=0.0
# epoch 4 -- batchNb 82: 0.05425539 0.0 --  lambda=0.0
# epoch 4 -- batchNb 83: 0.05401853 0.0 --  lambda=0.0
# epoch 4 -- batchNb 84: 0.050224848 0.0 --  lambda=0.0
# epoch 4 -- batchNb 85: 0.040660523 0.0 --  lambda=0.0
# epoch 4 -- batchNb 86: 0.04450938 0.0 --  lambda=0.0
# epoch 4 -- batchNb 87: 0.058698177 0.0 --  lambda=0.0
# epoch 4 -- batchNb 88: 0.0533124 0.0 --  lambda=0.0
# epoch 4 -- batchNb 89: 0.047156073 0.0 --  lambda=0.0
# epoch 4 -- batchNb 90: 0.04953282 0.0 --  lambda=0.0
# epoch 4 -- batchNb 91: 0.054977875 0.0 --  lambda=0.0
# epoch 4 -- batchNb 92: 0.04918219 0.0 --  lambda=0.0
# epoch 4 -- batchNb 93: 0.049258795 0.0 --  lambda=0.0
# epoch 4 -- batchNb 94: 0.03834324 0.0 --  lambda=0.0
# epoch 4 -- batchNb 95: 0.051889166 0.0 --  lambda=0.0
# epoch 4 -- batchNb 96: 0.061228655 0.0 --  lambda=0.0
# epoch 5 -- batchNb 1: 0.052666727 0.0 --  lambda=0.0
# epoch 5 -- batchNb 2: 0.05465804 0.0 --  lambda=0.0
# epoch 5 -- batchNb 3: 0.04040492 0.0 --  lambda=0.0
# epoch 5 -- batchNb 4: 0.05202254 0.0 --  lambda=0.0
# epoch 5 -- batchNb 5: 0.05278897 0.0 --  lambda=0.0
# epoch 5 -- batchNb 6: 0.05835273 0.0 --  lambda=0.0
# epoch 5 -- batchNb 7: 0.038802974 0.0 --  lambda=0.0
# epoch 5 -- batchNb 8: 0.04660015 0.0 --  lambda=0.0
# epoch 5 -- batchNb 9: 0.046545506 0.0 --  lambda=0.0
# epoch 5 -- batchNb 10: 0.06079308 0.0 --  lambda=0.0
# epoch 5 -- batchNb 11: 0.053692788 0.0 --  lambda=0.0
# epoch 5 -- batchNb 12: 0.051297568 0.0 --  lambda=0.0
# epoch 5 -- batchNb 13: 0.054882668 0.0 --  lambda=0.0
# epoch 5 -- batchNb 14: 0.057394832 0.0 --  lambda=0.0
# epoch 5 -- batchNb 15: 0.04397625 0.0 --  lambda=0.0
# epoch 5 -- batchNb 16: 0.04488722 0.0 --  lambda=0.0
# epoch 5 -- batchNb 17: 0.047060076 0.0 --  lambda=0.0
# epoch 5 -- batchNb 18: 0.04716309 0.0 --  lambda=0.0
# epoch 5 -- batchNb 19: 0.043970708 0.0 --  lambda=0.0
# epoch 5 -- batchNb 20: 0.045422662 0.0 --  lambda=0.0
# epoch 5 -- batchNb 21: 0.04985009 0.0 --  lambda=0.0
# epoch 5 -- batchNb 22: 0.049278773 0.0 --  lambda=0.0
# epoch 5 -- batchNb 23: 0.054574657 0.0 --  lambda=0.0
# epoch 5 -- batchNb 24: 0.047932338 0.0 --  lambda=0.0
# epoch 5 -- batchNb 25: 0.04495439 0.0 --  lambda=0.0
# epoch 5 -- batchNb 26: 0.04997645 0.0 --  lambda=0.0
# epoch 5 -- batchNb 27: 0.046300907 0.0 --  lambda=0.0
# epoch 5 -- batchNb 28: 0.049804125 0.0 --  lambda=0.0
# epoch 5 -- batchNb 29: 0.05383503 0.0 --  lambda=0.0
# epoch 5 -- batchNb 30: 0.053322565 0.0 --  lambda=0.0
# epoch 5 -- batchNb 31: 0.05931221 0.0 --  lambda=0.0
# epoch 5 -- batchNb 32: 0.05178261 0.0 --  lambda=0.0
# epoch 5 -- batchNb 33: 0.04673219 0.0 --  lambda=0.0
# epoch 5 -- batchNb 34: 0.06296995 0.0 --  lambda=0.0
# epoch 5 -- batchNb 35: 0.0438231 0.0 --  lambda=0.0
# epoch 5 -- batchNb 36: 0.05243313 0.0 --  lambda=0.0
# epoch 5 -- batchNb 37: 0.05448243 0.0 --  lambda=0.0
# epoch 5 -- batchNb 38: 0.052771006 0.0 --  lambda=0.0
# epoch 5 -- batchNb 39: 0.05529521 0.0 --  lambda=0.0
# epoch 5 -- batchNb 40: 0.04640995 0.0 --  lambda=0.0
# epoch 5 -- batchNb 41: 0.042673726 0.0 --  lambda=0.0
# epoch 5 -- batchNb 42: 0.048408054 0.0 --  lambda=0.0
# epoch 5 -- batchNb 43: 0.048731156 0.0 --  lambda=0.0
# epoch 5 -- batchNb 44: 0.06149238 0.0 --  lambda=0.0
# epoch 5 -- batchNb 45: 0.038775608 0.0 --  lambda=0.0
# epoch 5 -- batchNb 46: 0.056682054 0.0 --  lambda=0.0
# epoch 5 -- batchNb 47: 0.04404131 0.0 --  lambda=0.0
# epoch 5 -- batchNb 48: 0.050673846 0.0 --  lambda=0.0
# epoch 5 -- batchNb 49: 0.042878862 0.0 --  lambda=0.0
# epoch 5 -- batchNb 50: 0.04763547 0.0 --  lambda=0.0
# epoch 5 -- batchNb 51: 0.035712637 0.0 --  lambda=0.0
# epoch 5 -- batchNb 52: 0.049984563 0.0 --  lambda=0.0
# epoch 5 -- batchNb 53: 0.04967577 0.0 --  lambda=0.0
# epoch 5 -- batchNb 54: 0.053324543 0.0 --  lambda=0.0
# epoch 5 -- batchNb 55: 0.054891743 0.0 --  lambda=0.0
# epoch 5 -- batchNb 56: 0.055268593 0.0 --  lambda=0.0
# epoch 5 -- batchNb 57: 0.05089426 0.0 --  lambda=0.0
# epoch 5 -- batchNb 58: 0.039547876 0.0 --  lambda=0.0
# epoch 5 -- batchNb 59: 0.049684793 0.0 --  lambda=0.0
# epoch 5 -- batchNb 60: 0.036698475 0.0 --  lambda=0.0
# epoch 5 -- batchNb 61: 0.04146537 0.0 --  lambda=0.0
# epoch 5 -- batchNb 62: 0.04065614 0.0 --  lambda=0.0
# epoch 5 -- batchNb 63: 0.041759845 0.0 --  lambda=0.0
# epoch 5 -- batchNb 64: 0.048984528 0.0 --  lambda=0.0
# epoch 5 -- batchNb 65: 0.0526136 0.0 --  lambda=0.0
# epoch 5 -- batchNb 66: 0.042788 0.0 --  lambda=0.0
# epoch 5 -- batchNb 67: 0.049702283 0.0 --  lambda=0.0
# epoch 5 -- batchNb 68: 0.03926361 0.0 --  lambda=0.0
# epoch 5 -- batchNb 69: 0.044362277 0.0 --  lambda=0.0
# epoch 5 -- batchNb 70: 0.061365116 0.0 --  lambda=0.0
# epoch 5 -- batchNb 71: 0.04872025 0.0 --  lambda=0.0
# epoch 5 -- batchNb 72: 0.04897994 0.0 --  lambda=0.0
# epoch 5 -- batchNb 73: 0.049062543 0.0 --  lambda=0.0
# epoch 5 -- batchNb 74: 0.060598947 0.0 --  lambda=0.0
# epoch 5 -- batchNb 75: 0.049625754 0.0 --  lambda=0.0
# epoch 5 -- batchNb 76: 0.039966136 0.0 --  lambda=0.0
# epoch 5 -- batchNb 77: 0.056859408 0.0 --  lambda=0.0
# epoch 5 -- batchNb 78: 0.058535043 0.0 --  lambda=0.0
# epoch 5 -- batchNb 79: 0.038509574 0.0 --  lambda=0.0
# epoch 5 -- batchNb 80: 0.04397496 0.0 --  lambda=0.0
# epoch 5 -- batchNb 81: 0.03893575 0.0 --  lambda=0.0
# epoch 5 -- batchNb 82: 0.0485379 0.0 --  lambda=0.0
# epoch 5 -- batchNb 83: 0.053659435 0.0 --  lambda=0.0
# epoch 5 -- batchNb 84: 0.06516526 0.0 --  lambda=0.0
# epoch 5 -- batchNb 85: 0.045761243 0.0 --  lambda=0.0
# epoch 5 -- batchNb 86: 0.041311607 0.0 --  lambda=0.0
# epoch 5 -- batchNb 87: 0.042448677 0.0 --  lambda=0.0
# epoch 5 -- batchNb 88: 0.05849885 0.0 --  lambda=0.0
# epoch 5 -- batchNb 89: 0.053702507 0.0 --  lambda=0.0
# epoch 5 -- batchNb 90: 0.035776343 0.0 --  lambda=0.0
# epoch 5 -- batchNb 91: 0.038767487 0.0 --  lambda=0.0
# epoch 5 -- batchNb 92: 0.053827036 0.0 --  lambda=0.0
# epoch 5 -- batchNb 93: 0.04502975 0.0 --  lambda=0.0
# epoch 5 -- batchNb 94: 0.04219799 0.0 --  lambda=0.0
# epoch 5 -- batchNb 95: 0.049473416 0.0 --  lambda=0.0
# epoch 5 -- batchNb 96: 0.04045 0.0 --  lambda=0.0
# epoch 6 -- batchNb 1: 0.050840903 0.0 --  lambda=0.0
# epoch 6 -- batchNb 2: 0.054172527 0.0 --  lambda=0.0
# epoch 6 -- batchNb 3: 0.045672506 0.0 --  lambda=0.0
# epoch 6 -- batchNb 4: 0.044477753 0.0 --  lambda=0.0
# epoch 6 -- batchNb 5: 0.05550393 0.0 --  lambda=0.0
# epoch 6 -- batchNb 6: 0.043273844 0.0 --  lambda=0.0
# epoch 6 -- batchNb 7: 0.059931565 0.0 --  lambda=0.0
# epoch 6 -- batchNb 8: 0.050799552 0.0 --  lambda=0.0
# epoch 6 -- batchNb 9: 0.036747262 0.0 --  lambda=0.0
# epoch 6 -- batchNb 10: 0.038292345 0.0 --  lambda=0.0
# epoch 6 -- batchNb 11: 0.06030621 0.0 --  lambda=0.0
# epoch 6 -- batchNb 12: 0.049121518 0.0 --  lambda=0.0
# epoch 6 -- batchNb 13: 0.051432647 0.0 --  lambda=0.0
# epoch 6 -- batchNb 14: 0.047200073 0.0 --  lambda=0.0
# epoch 6 -- batchNb 15: 0.058282737 0.0 --  lambda=0.0
# epoch 6 -- batchNb 16: 0.040567007 0.0 --  lambda=0.0
# epoch 6 -- batchNb 17: 0.053349134 0.0 --  lambda=0.0
# epoch 6 -- batchNb 18: 0.046708364 0.0 --  lambda=0.0
# epoch 6 -- batchNb 19: 0.047933593 0.0 --  lambda=0.0
# epoch 6 -- batchNb 20: 0.05355089 0.0 --  lambda=0.0
# epoch 6 -- batchNb 21: 0.0528112 0.0 --  lambda=0.0
# epoch 6 -- batchNb 22: 0.056264896 0.0 --  lambda=0.0
# epoch 6 -- batchNb 23: 0.04417181 0.0 --  lambda=0.0
# epoch 6 -- batchNb 24: 0.036018215 0.0 --  lambda=0.0
# epoch 6 -- batchNb 25: 0.057531066 0.0 --  lambda=0.0
# epoch 6 -- batchNb 26: 0.04296656 0.0 --  lambda=0.0
# epoch 6 -- batchNb 27: 0.060769893 0.0 --  lambda=0.0
# epoch 6 -- batchNb 28: 0.041431017 0.0 --  lambda=0.0
# epoch 6 -- batchNb 29: 0.048783075 0.0 --  lambda=0.0
# epoch 6 -- batchNb 30: 0.04632821 0.0 --  lambda=0.0
# epoch 6 -- batchNb 31: 0.041381806 0.0 --  lambda=0.0
# epoch 6 -- batchNb 32: 0.047459744 0.0 --  lambda=0.0
# epoch 6 -- batchNb 33: 0.051179763 0.0 --  lambda=0.0
# epoch 6 -- batchNb 34: 0.05036141 0.0 --  lambda=0.0
# epoch 6 -- batchNb 35: 0.05010493 0.0 --  lambda=0.0
# epoch 6 -- batchNb 36: 0.0423872 0.0 --  lambda=0.0
# epoch 6 -- batchNb 37: 0.044339675 0.0 --  lambda=0.0
# epoch 6 -- batchNb 38: 0.050756134 0.0 --  lambda=0.0
# epoch 6 -- batchNb 39: 0.059923653 0.0 --  lambda=0.0
# epoch 6 -- batchNb 40: 0.034396697 0.0 --  lambda=0.0
# epoch 6 -- batchNb 41: 0.042127486 0.0 --  lambda=0.0
# epoch 6 -- batchNb 42: 0.04815972 0.0 --  lambda=0.0
# epoch 6 -- batchNb 43: 0.035388395 0.0 --  lambda=0.0
# epoch 6 -- batchNb 44: 0.04001459 0.0 --  lambda=0.0
# epoch 6 -- batchNb 45: 0.043022297 0.0 --  lambda=0.0
# epoch 6 -- batchNb 46: 0.04549095 0.0 --  lambda=0.0
# epoch 6 -- batchNb 47: 0.047983095 0.0 --  lambda=0.0
# epoch 6 -- batchNb 48: 0.054423742 0.0 --  lambda=0.0
# epoch 6 -- batchNb 49: 0.04109533 0.0 --  lambda=0.0
# epoch 6 -- batchNb 50: 0.04209818 0.0 --  lambda=0.0
# epoch 6 -- batchNb 51: 0.043920994 0.0 --  lambda=0.0
# epoch 6 -- batchNb 52: 0.0446004 0.0 --  lambda=0.0
# epoch 6 -- batchNb 53: 0.036934055 0.0 --  lambda=0.0
# epoch 6 -- batchNb 54: 0.041057855 0.0 --  lambda=0.0
# epoch 6 -- batchNb 55: 0.040995184 0.0 --  lambda=0.0
# epoch 6 -- batchNb 56: 0.046985663 0.0 --  lambda=0.0
# epoch 6 -- batchNb 57: 0.050078236 0.0 --  lambda=0.0
# epoch 6 -- batchNb 58: 0.056559447 0.0 --  lambda=0.0
# epoch 6 -- batchNb 59: 0.036271166 0.0 --  lambda=0.0
# epoch 6 -- batchNb 60: 0.044821125 0.0 --  lambda=0.0
# epoch 6 -- batchNb 61: 0.04258202 0.0 --  lambda=0.0
# epoch 6 -- batchNb 62: 0.04920227 0.0 --  lambda=0.0
# epoch 6 -- batchNb 63: 0.040805444 0.0 --  lambda=0.0
# epoch 6 -- batchNb 64: 0.046837624 0.0 --  lambda=0.0
# epoch 6 -- batchNb 65: 0.039369654 0.0 --  lambda=0.0
# epoch 6 -- batchNb 66: 0.04308677 0.0 --  lambda=0.0
# epoch 6 -- batchNb 67: 0.038223043 0.0 --  lambda=0.0
# epoch 6 -- batchNb 68: 0.04349736 0.0 --  lambda=0.0
# epoch 6 -- batchNb 69: 0.04212994 0.0 --  lambda=0.0
# epoch 6 -- batchNb 70: 0.042355552 0.0 --  lambda=0.0
# epoch 6 -- batchNb 71: 0.04113878 0.0 --  lambda=0.0
# epoch 6 -- batchNb 72: 0.04884817 0.0 --  lambda=0.0
# epoch 6 -- batchNb 73: 0.044608954 0.0 --  lambda=0.0
# epoch 6 -- batchNb 74: 0.05068469 0.0 --  lambda=0.0
# epoch 6 -- batchNb 75: 0.047934238 0.0 --  lambda=0.0
# epoch 6 -- batchNb 76: 0.045793436 0.0 --  lambda=0.0
# epoch 6 -- batchNb 77: 0.042978164 0.0 --  lambda=0.0
# epoch 6 -- batchNb 78: 0.040392842 0.0 --  lambda=0.0
# epoch 6 -- batchNb 79: 0.048739813 0.0 --  lambda=0.0
# epoch 6 -- batchNb 80: 0.030470595 0.0 --  lambda=0.0
# epoch 6 -- batchNb 81: 0.041947022 0.0 --  lambda=0.0
# epoch 6 -- batchNb 82: 0.044847205 0.0 --  lambda=0.0
# epoch 6 -- batchNb 83: 0.054011118 0.0 --  lambda=0.0
# epoch 6 -- batchNb 84: 0.047931146 0.0 --  lambda=0.0
# epoch 6 -- batchNb 85: 0.041964278 0.0 --  lambda=0.0
# epoch 6 -- batchNb 86: 0.038655456 0.0 --  lambda=0.0
# epoch 6 -- batchNb 87: 0.035121016 0.0 --  lambda=0.0
# epoch 6 -- batchNb 88: 0.041549087 0.0 --  lambda=0.0
# epoch 6 -- batchNb 89: 0.040767744 0.0 --  lambda=0.0
# epoch 6 -- batchNb 90: 0.04357457 0.0 --  lambda=0.0
# epoch 6 -- batchNb 91: 0.04528727 0.0 --  lambda=0.0
# epoch 6 -- batchNb 92: 0.054771826 0.0 --  lambda=0.0
# epoch 6 -- batchNb 93: 0.053154234 0.0 --  lambda=0.0
# epoch 6 -- batchNb 94: 0.045022033 0.0 --  lambda=0.0
# epoch 6 -- batchNb 95: 0.044255618 0.0 --  lambda=0.0
# epoch 6 -- batchNb 96: 0.044832762 0.0 --  lambda=0.0
# epoch 7 -- batchNb 1: 0.042165563 0.0 --  lambda=0.0
# epoch 7 -- batchNb 2: 0.04288362 0.0 --  lambda=0.0
# epoch 7 -- batchNb 3: 0.04604016 0.0 --  lambda=0.0
# epoch 7 -- batchNb 4: 0.046990138 0.0 --  lambda=0.0
# epoch 7 -- batchNb 5: 0.047319535 0.0 --  lambda=0.0
# epoch 7 -- batchNb 6: 0.04542859 0.0 --  lambda=0.0
# epoch 7 -- batchNb 7: 0.038825024 0.0 --  lambda=0.0
# epoch 7 -- batchNb 8: 0.04753358 0.0 --  lambda=0.0
# epoch 7 -- batchNb 9: 0.04267575 0.0 --  lambda=0.0
# epoch 7 -- batchNb 10: 0.048919037 0.0 --  lambda=0.0
# epoch 7 -- batchNb 11: 0.045500584 0.0 --  lambda=0.0
# epoch 7 -- batchNb 12: 0.042007457 0.0 --  lambda=0.0
# epoch 7 -- batchNb 13: 0.048444096 0.0 --  lambda=0.0
# epoch 7 -- batchNb 14: 0.045876943 0.0 --  lambda=0.0
# epoch 7 -- batchNb 15: 0.044910017 0.0 --  lambda=0.0
# epoch 7 -- batchNb 16: 0.047091603 0.0 --  lambda=0.0
# epoch 7 -- batchNb 17: 0.048212115 0.0 --  lambda=0.0
# epoch 7 -- batchNb 18: 0.03471845 0.0 --  lambda=0.0
# epoch 7 -- batchNb 19: 0.040174343 0.0 --  lambda=0.0
# epoch 7 -- batchNb 20: 0.03821547 0.0 --  lambda=0.0
# epoch 7 -- batchNb 21: 0.04209218 0.0 --  lambda=0.0
# epoch 7 -- batchNb 22: 0.043643054 0.0 --  lambda=0.0
# epoch 7 -- batchNb 23: 0.04470536 0.0 --  lambda=0.0
# epoch 7 -- batchNb 24: 0.04652655 0.0 --  lambda=0.0
# epoch 7 -- batchNb 25: 0.0446738 0.0 --  lambda=0.0
# epoch 7 -- batchNb 26: 0.038649574 0.0 --  lambda=0.0
# epoch 7 -- batchNb 27: 0.046021495 0.0 --  lambda=0.0
# epoch 7 -- batchNb 28: 0.04242356 0.0 --  lambda=0.0
# epoch 7 -- batchNb 29: 0.04716338 0.0 --  lambda=0.0
# epoch 7 -- batchNb 30: 0.04462794 0.0 --  lambda=0.0
# epoch 7 -- batchNb 31: 0.044080503 0.0 --  lambda=0.0
# epoch 7 -- batchNb 32: 0.04320191 0.0 --  lambda=0.0
# epoch 8 -- batchNb 1: 0.045218714 0.0 --  lambda=0.0
# epoch 8 -- batchNb 2: 0.042371757 0.0 --  lambda=0.0
# epoch 8 -- batchNb 3: 0.038145848 0.0 --  lambda=0.0
# epoch 8 -- batchNb 4: 0.039944615 0.0 --  lambda=0.0
# epoch 8 -- batchNb 5: 0.042540204 0.0 --  lambda=0.0
# epoch 8 -- batchNb 6: 0.035266932 0.0 --  lambda=0.0
# epoch 8 -- batchNb 7: 0.04411637 0.0 --  lambda=0.0
# epoch 8 -- batchNb 8: 0.039307293 0.0 --  lambda=0.0
# epoch 8 -- batchNb 9: 0.040965423 0.0 --  lambda=0.0
# epoch 8 -- batchNb 10: 0.042381946 0.0 --  lambda=0.0
# epoch 8 -- batchNb 11: 0.045671005 0.0 --  lambda=0.0
# epoch 8 -- batchNb 12: 0.048896365 0.0 --  lambda=0.0
# epoch 8 -- batchNb 13: 0.03866689 0.0 --  lambda=0.0
# epoch 8 -- batchNb 14: 0.048118874 0.0 --  lambda=0.0
# epoch 8 -- batchNb 15: 0.049000822 0.0 --  lambda=0.0
# epoch 8 -- batchNb 16: 0.040825877 0.0 --  lambda=0.0
# epoch 8 -- batchNb 17: 0.040715713 0.0 --  lambda=0.0
# epoch 8 -- batchNb 18: 0.040178288 0.0 --  lambda=0.0
# epoch 8 -- batchNb 19: 0.036842838 0.0 --  lambda=0.0
# epoch 8 -- batchNb 20: 0.03786043 0.0 --  lambda=0.0
# epoch 8 -- batchNb 21: 0.041941885 0.0 --  lambda=0.0
# epoch 8 -- batchNb 22: 0.04324492 0.0 --  lambda=0.0
# epoch 8 -- batchNb 23: 0.042395942 0.0 --  lambda=0.0
# epoch 8 -- batchNb 24: 0.036186468 0.0 --  lambda=0.0
# epoch 8 -- batchNb 25: 0.037065115 0.0 --  lambda=0.0
# epoch 8 -- batchNb 26: 0.054943986 0.0 --  lambda=0.0
# epoch 8 -- batchNb 27: 0.034587696 0.0 --  lambda=0.0
# epoch 8 -- batchNb 28: 0.045947295 0.0 --  lambda=0.0
# epoch 8 -- batchNb 29: 0.046744723 0.0 --  lambda=0.0
# epoch 8 -- batchNb 30: 0.043306578 0.0 --  lambda=0.0
# epoch 8 -- batchNb 31: 0.043897495 0.0 --  lambda=0.0
# epoch 8 -- batchNb 32: 0.040863916 0.0 --  lambda=0.0
# epoch 9 -- batchNb 1: 0.036401574 0.0 --  lambda=0.0
# epoch 9 -- batchNb 2: 0.044728376 0.0 --  lambda=0.0
# epoch 9 -- batchNb 3: 0.041221824 0.0 --  lambda=0.0
# epoch 9 -- batchNb 4: 0.041293032 0.0 --  lambda=0.0
# epoch 9 -- batchNb 5: 0.04077698 0.0 --  lambda=0.0
# epoch 9 -- batchNb 6: 0.04162327 0.0 --  lambda=0.0
# epoch 9 -- batchNb 7: 0.040318727 0.0 --  lambda=0.0
# epoch 9 -- batchNb 8: 0.03744067 0.0 --  lambda=0.0
# epoch 9 -- batchNb 9: 0.04151905 0.0 --  lambda=0.0
# epoch 9 -- batchNb 10: 0.0454321 0.0 --  lambda=0.0
# epoch 9 -- batchNb 11: 0.04335966 0.0 --  lambda=0.0
# epoch 9 -- batchNb 12: 0.04293219 0.0 --  lambda=0.0
# epoch 9 -- batchNb 13: 0.036662344 0.0 --  lambda=0.0
# epoch 9 -- batchNb 14: 0.03558317 0.0 --  lambda=0.0
# epoch 9 -- batchNb 15: 0.044930156 0.0 --  lambda=0.0
# epoch 9 -- batchNb 16: 0.039628062 0.0 --  lambda=0.0
# Run training - with reg
# epoch 0 -- batchNb 1: 0.23156622 0.0001896890902702648 --  lambda=0.0005
# epoch 0 -- batchNb 2: 0.23717503 0.0002871323497500898 --  lambda=0.0005
# epoch 0 -- batchNb 3: 0.22913279 0.00033566901998582406 --  lambda=0.0005
# epoch 0 -- batchNb 4: 0.22398035 0.0008797886916028399 --  lambda=0.0005
# epoch 0 -- batchNb 5: 0.225346 0.0012783952540888187 --  lambda=0.0005
# epoch 0 -- batchNb 6: 0.2147439 0.0028787580161851217 --  lambda=0.0005
# epoch 0 -- batchNb 7: 0.21309437 0.001222823003548908 --  lambda=0.0005
# epoch 0 -- batchNb 8: 0.21112871 0.0026505191085908547 --  lambda=0.0005
# epoch 0 -- batchNb 9: 0.204436 0.005623527154004557 --  lambda=0.0005
# epoch 0 -- batchNb 10: 0.20658146 0.00522755565188375 --  lambda=0.0005
# epoch 0 -- batchNb 11: 0.20464276 0.00659886294634973 --  lambda=0.0005
# epoch 0 -- batchNb 12: 0.19918638 0.007656436048650112 --  lambda=0.0005
# epoch 0 -- batchNb 13: 0.19355719 0.0042894888877928 --  lambda=0.0005
# epoch 0 -- batchNb 14: 0.18603824 0.01605264489048239 --  lambda=0.0005
# epoch 0 -- batchNb 15: 0.18084587 0.007844918730039908 --  lambda=0.0005
# epoch 0 -- batchNb 16: 0.19671732 0.013213403689669417 --  lambda=0.0005
# epoch 0 -- batchNb 17: 0.1835331 0.020550680733477437 --  lambda=0.0005
# epoch 0 -- batchNb 18: 0.18281059 0.021112316497110636 --  lambda=0.0005
# epoch 0 -- batchNb 19: 0.17335106 0.02009133976046869 --  lambda=0.0005
# epoch 0 -- batchNb 20: 0.17784062 0.027464541063312007 --  lambda=0.0005
# epoch 0 -- batchNb 21: 0.16333814 0.027881125056367653 --  lambda=0.0005
# epoch 0 -- batchNb 22: 0.17541388 0.022150219827124694 --  lambda=0.0005
# epoch 0 -- batchNb 23: 0.16516358 0.03199141418521651 --  lambda=0.0005
# epoch 0 -- batchNb 24: 0.16332537 0.013962157206387448 --  lambda=0.0005
# epoch 0 -- batchNb 25: 0.15499716 0.0317444284650499 --  lambda=0.0005
# epoch 0 -- batchNb 26: 0.15382135 0.036433695670833974 --  lambda=0.0005
# epoch 0 -- batchNb 27: 0.15513782 0.032055098191918895 --  lambda=0.0005
# epoch 0 -- batchNb 28: 0.16360243 0.030047023629883533 --  lambda=0.0005
# epoch 0 -- batchNb 29: 0.15501963 0.04502229687949446 --  lambda=0.0005
# epoch 0 -- batchNb 30: 0.14732699 0.04631435623578247 --  lambda=0.0005
# epoch 0 -- batchNb 31: 0.14977536 0.04139711322342548 --  lambda=0.0005
# epoch 0 -- batchNb 32: 0.15043928 0.04283967106573466 --  lambda=0.0005
# epoch 0 -- batchNb 33: 0.13912089 0.05085698914841874 --  lambda=0.0005
# epoch 0 -- batchNb 34: 0.1489228 0.06716793881758587 --  lambda=0.0005
# epoch 0 -- batchNb 35: 0.1526454 0.04128239518120047 --  lambda=0.0005
# epoch 0 -- batchNb 36: 0.1509096 0.04818125888075434 --  lambda=0.0005
# epoch 0 -- batchNb 37: 0.14245906 0.04915383197483368 --  lambda=0.0005
# epoch 0 -- batchNb 38: 0.1495417 0.036089343915155794 --  lambda=0.0005
# epoch 0 -- batchNb 39: 0.14512189 0.05125616967530702 --  lambda=0.0005
# epoch 0 -- batchNb 40: 0.14858098 0.07273262462828751 --  lambda=0.0005
# epoch 0 -- batchNb 41: 0.1348761 0.049383057835297464 --  lambda=0.0005
# epoch 0 -- batchNb 42: 0.1401427 0.05478558712326294 --  lambda=0.0005
# epoch 0 -- batchNb 43: 0.12528509 0.06438868118504977 --  lambda=0.0005
# epoch 0 -- batchNb 44: 0.14314483 0.04578360460618226 --  lambda=0.0005
# epoch 0 -- batchNb 45: 0.13684937 0.039833905202499874 --  lambda=0.0005
# epoch 0 -- batchNb 46: 0.13695505 0.04670971526526954 --  lambda=0.0005
# epoch 0 -- batchNb 47: 0.1382585 0.052683654955651534 --  lambda=0.0005
# epoch 0 -- batchNb 48: 0.11677228 0.05198810500257975 --  lambda=0.0005
# epoch 0 -- batchNb 49: 0.1389003 0.05559236598161499 --  lambda=0.0005
# epoch 0 -- batchNb 50: 0.13187185 0.07096012840968727 --  lambda=0.0005
# epoch 0 -- batchNb 51: 0.13300839 0.0743572982682335 --  lambda=0.0005
# epoch 0 -- batchNb 52: 0.13079025 0.06500704241301708 --  lambda=0.0005
# epoch 0 -- batchNb 53: 0.13135405 0.09874934557594967 --  lambda=0.0005
# epoch 0 -- batchNb 54: 0.11574639 0.05664572082767985 --  lambda=0.0005
# epoch 0 -- batchNb 55: 0.11954458 0.04969655077301604 --  lambda=0.0005
# epoch 0 -- batchNb 56: 0.12188701 0.07593203547405293 --  lambda=0.0005
# epoch 0 -- batchNb 57: 0.12648658 0.06707519847518449 --  lambda=0.0005
# epoch 0 -- batchNb 58: 0.13099831 0.07217201203235339 --  lambda=0.0005
# epoch 0 -- batchNb 59: 0.12643458 0.06331423004516275 --  lambda=0.0005
# epoch 0 -- batchNb 60: 0.13099517 0.06683201018295953 --  lambda=0.0005
# epoch 0 -- batchNb 61: 0.1249593 0.10165555698248811 --  lambda=0.0005
# epoch 0 -- batchNb 62: 0.123089425 0.07947895994781275 --  lambda=0.0005
# epoch 0 -- batchNb 63: 0.119636536 0.07104755354898167 --  lambda=0.0005
# epoch 0 -- batchNb 64: 0.12658584 0.06672724607155253 --  lambda=0.0005
# epoch 0 -- batchNb 65: 0.12602748 0.07426226047739118 --  lambda=0.0005
# epoch 0 -- batchNb 66: 0.11014847 0.10933540085001209 --  lambda=0.0005
# epoch 0 -- batchNb 67: 0.118347 0.145664749817367 --  lambda=0.0005
# epoch 0 -- batchNb 68: 0.121450126 0.09428176805677839 --  lambda=0.0005
# epoch 0 -- batchNb 69: 0.118876874 0.051385229774438594 --  lambda=0.0005
# epoch 9 -- batchNb 6: 0.09354857 0.12639203194105272 --  lambda=0.0005
# epoch 9 -- batchNb 7: 0.08996671 0.09332533706650462 --  lambda=0.0005
# epoch 9 -- batchNb 8: 0.08648964 0.13888273593308395 --  lambda=0.0005
# epoch 9 -- batchNb 9: 0.09052658 0.07491041092223295 --  lambda=0.0005
# epoch 9 -- batchNb 10: 0.091657534 0.18232393921130158 --  lambda=0.0005
# epoch 9 -- batchNb 11: 0.092016034 0.0961013601171485 --  lambda=0.0005
# epoch 9 -- batchNb 12: 0.0940389 0.09714355176131029 --  lambda=0.0005
# epoch 9 -- batchNb 13: 0.09415238 0.16035001118716774 --  lambda=0.0005
# epoch 9 -- batchNb 14: 0.090611584 0.14054674026505296 --  lambda=0.0005
# epoch 9 -- batchNb 15: 0.09109485 0.16914215543153238 --  lambda=0.0005
# epoch 9 -- batchNb 16: 0.09215825 0.11387224011579905 --  lambda=0.0005

# %% [markdown]
# **Tests - without regularisation**

# %%
predY_test=torch.clone(W2Rcore.LargeDatasetPred(model_no_reg,X_bw_test.float(),10000,DEVICE=DEVICE))  #prediction made with blocks of 10000 observations to make sure we won't saturate the memory
    
error = nn.MSELoss()  #does not take into account the W2 metric

loss = error(predY_test, Titles_test.float())
    
tmp_loss=loss.data
print('Loss (test data): '+str(tmp_loss))
            
y_pred_np=1*(predY_test.view(-1).data.numpy()>0.5)
y_true_np=1*(Titles_test.view(-1).data.numpy()>0.5)
S_np=Gen_test[:]
    
tmp_DI=W2Rmisc.compute_disparate_impact(y_pred_np, S_np)
print('DI:',tmp_DI)
    
tmp_cm=W2Rmisc.cpt_BasicDescrStats(y_pred_np, y_true_np, S_np)   
print('s0_RatioGoodPred:',tmp_cm['s0_RatioGoodPred'])
print('s1_RatioGoodPred:',tmp_cm['s1_RatioGoodPred'])

mse = sum((y_pred_np-y_true_np)**2) / len(y_true_np)
print("MSE :",mse)

Accuracy=accuracy_score(y_true_np, y_pred_np)

y_pred_torch=torch.FloatTensor(y_pred_np)
y_pred_torch=y_pred_torch.reshape(y_pred_torch.shape[0],1)
y_true_torch=torch.FloatTensor(y_true_np)
y_true_torch=y_pred_torch.reshape(y_true_torch.shape[0],1)

result=W2Rcore.EstimGrad_W2dist(Gen_test,y_pred_torch,y_true_torch,Gen_test,y_pred_torch,y_true_torch, NbBins=500,ID_TreatedVar=0,DistBetween='All predictions')
W_score=result[1]
# Out:
# Loss (test data): tensor(0.0415)
# DI: 0.1923039963407927
# s0_RatioGoodPred: 0.9409306742640076
# s1_RatioGoodPred: 0.9614980289093298
# MSE : 0.0469126213592233

# %% [markdown]
# **Tests - with regularisation**

# %%
predY_test=torch.clone(W2Rcore.LargeDatasetPred(model_reg,X_bw_test.float(),10000,DEVICE=DEVICE))  #prediction made with blocks of 10000 observations to make sure we won't saturate the memory
    
error = nn.MSELoss()  #does not take into account the W2 metric
loss = error(predY_test, Titles_test.float())
    
tmp_loss=loss.data 
print('Loss (test data): '+str(tmp_loss))
            
y_pred_np=1*(predY_test.view(-1).data.numpy()>0.5)
y_true_np=1*(Titles_test.view(-1).data.numpy()>0.5)
S_np=Gen_test[:]
    
tmp_DI_r=W2Rmisc.compute_disparate_impact(y_pred_np, S_np)
print('DI:',tmp_DI_r) 
    
tmp_cm_r=W2Rmisc.cpt_BasicDescrStats(y_pred_np, y_true_np, S_np)  
print('s0_RatioGoodPred:',tmp_cm_r['s0_RatioGoodPred'])
print('s1_RatioGoodPred:',tmp_cm_r['s1_RatioGoodPred'])

mse_r = sum((y_pred_np-y_true_np)**2) / len(y_true_np)
print("MSE :",mse_r)

Accuracy_r=accuracy_score(y_true_np, y_pred_np)
print("Accuracy", Accuracy_r)

y_pred_torch=torch.FloatTensor(y_pred_np)
y_pred_torch=y_pred_torch.reshape(y_pred_torch.shape[0],1)
y_true_torch=torch.FloatTensor(y_true_np)
y_true_torch=y_pred_torch.reshape(y_true_torch.shape[0],1)

result_r=W2Rcore.EstimGrad_W2dist(Gen_test,y_pred_torch,y_true_torch,Gen_test,y_pred_torch,y_true_torch, NbBins=500,ID_TreatedVar=0,DistBetween='All predictions')
W_score_r=result_r[1]
# Out:
# Loss (test data): tensor(0.0955)
# DI: 0.1843403110200781
# s0_RatioGoodPred: 0.9471984805318139
# s1_RatioGoodPred: 0.9478318002628121
# MSE : 0.05242718446601942
# Accuracy 0.9475728155339805

# %%
plt.figure()
plt.plot(result[2],'r',label="S0")
plt.plot(result[3],'b',label="S1")
plt.plot(result_r[2],'r--',label="S0_r")
plt.plot(result_r[3],'b--',label="S1_r")
plt.xlim(0, 5)
plt.ylim(0,1.02)
plt.legend()
plt.show()

plt.figure()
plt.plot(result[2],'r',label="S0")
plt.plot(result[3],'b',label="S1")
plt.plot(result_r[2],'r--',label="S0_r")
plt.plot(result_r[3],'b--',label="S1_r")
plt.xlim(495, 500)
plt.ylim(0,1.02)
plt.legend()
plt.show()

# %%
#lambda_=[]
#lambda_r=[]
#DI=[]
#DI_r=[]
#MSE=[]
#MSE_r=[]
#s0RGP=[]
#s1RGP=[]
#s0RGP_r=[]
#s1RGP_r=[]
#accuracy=[]
#accuracy_r=[]
#W=[]
#W_r=[]

# %%
lambda_.append(lambdavar)
lambda_r.append(lambdavar_r)

DI.append(tmp_DI)
DI_r.append(tmp_DI_r)

MSE.append(mse)
MSE_r.append(mse_r)

s0RGP.append(tmp_cm['s0_RatioGoodPred'])
s1RGP.append(tmp_cm['s1_RatioGoodPred']) 

s0RGP_r.append(tmp_cm_r['s0_RatioGoodPred'])
s1RGP_r.append(tmp_cm_r['s1_RatioGoodPred'])

accuracy.append(Accuracy)
accuracy_r.append(Accuracy_r)

W.append(W_score)
W_r.append(W_score_r)

# %% [markdown]
# ## Visualization

# %%
#Accuracy
plt.figure()
plt.scatter(lambda_, accuracy, color='blue')
plt.scatter(lambda_r, accuracy_r, color='blue')
plt.xlabel('lambda')
plt.ylabel('précision')
plt.title("Accuracy")
plt.savefig('Accuracy_reg.pdf')

#DI
plt.figure()
plt.scatter(lambda_, DI, color='blue')
plt.scatter(lambda_r, DI_r, color='blue')
plt.xlabel('lambda')
plt.title("DI")
plt.savefig('DI_reg.pdf')


#MSE
plt.figure()
plt.scatter(lambda_, MSE, color='blue')
plt.scatter(lambda_r, MSE_r, color='blue')
plt.xlabel('lambda')
plt.title("MSE")
plt.savefig('MSE_reg.pdf')

#Ratio good pred
plt.figure()
plt.scatter(lambda_, s1RGP, label="s1", color='red')
plt.scatter(lambda_, s0RGP, label="s0", color='blue')
plt.scatter(lambda_r, s0RGP_r, color='blue')
plt.scatter(lambda_r, s1RGP_r, color='red')
plt.xlabel('lambda')
plt.title("RatioGoodPred")
plt.legend()
plt.savefig('RatioGoodPred_reg.pdf')

#W score
plt.figure()
plt.scatter(lambda_, W, color='blue')
plt.scatter(lambda_r, W_r, color='blue')
plt.xlabel('lambda')
plt.title("W score")
plt.savefig('W_reg.pdf')

# %% [markdown]
# ## Without gender information

# %%
#parametres

input_size = len(X_bw_nogen_train[0])
#print(input_size) pourquoi 1006 et pas 1000
opti_lr = 1e-3 #le pas d'apprentissage

# %%
EPOCHS_in = 5 
BATCH_SIZE_in = 200 
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')  

#without regularisation risque Overfitting

model_no_reg_nogen = Logistic_Reg_model(input_size)


print('Run training - without reg') 

Lists_Results_nogen=W2Rcore.W2R_fit(model_no_reg_nogen,X_bw_nogen_train,Titles_train, Gen_train, lambdavar, EPOCHS = EPOCHS_in, BATCH_SIZE = BATCH_SIZE_in,obs_for_histo=50,DistBetween='All_predictions',DEVICE=DEVICE)

plt.figure()
plt.plot(Lists_Results_nogen['Acc'],'g--',label='Error rate')
plt.xlabel('Iterations ($\lambda=$'+str(lambdavar)+')')
plt.legend()
plt.savefig('Convergence_'+str(lambdavar)+'_noreg.pdf')

#with regularisation risque Underfitting

model_reg_nogen = Logistic_Reg_model(input_size)

print('Run training - with reg')
Lists_Results_nogen=W2Rcore.W2R_fit(model_reg_nogen,X_bw_nogen_train,Titles_train, Gen_train, lambdavar_r, EPOCHS = EPOCHS_in, BATCH_SIZE = BATCH_SIZE_in,obs_for_histo=50,DistBetween='All_predictions',DEVICE=DEVICE)

plt.figure()
plt.plot(Lists_Results_nogen['Acc'],'g--',label='Error rate')
#plt.plot(lambdavar*np.array(Lists_Results['W2']),'r-',label='$\lambda$*W2')
plt.xlabel('Iterations ($\lambda=$'+str(lambdavar_r)+')')
plt.legend()
plt.savefig('Convergence_'+str(lambdavar_r)+'_reg.pdf')
# Out:
# Run training - without reg
# epoch 0 -- batchNb 1: 0.23349373 0.0 --  lambda=0.0
# epoch 0 -- batchNb 2: 0.23095092 0.0 --  lambda=0.0
# epoch 0 -- batchNb 3: 0.22170943 0.0 --  lambda=0.0
# epoch 0 -- batchNb 4: 0.22310704 0.0 --  lambda=0.0
# epoch 0 -- batchNb 5: 0.22358853 0.0 --  lambda=0.0
# epoch 0 -- batchNb 6: 0.21145359 0.0 --  lambda=0.0
# epoch 0 -- batchNb 7: 0.20727067 0.0 --  lambda=0.0
# epoch 0 -- batchNb 8: 0.20523433 0.0 --  lambda=0.0
# epoch 0 -- batchNb 9: 0.1964127 0.0 --  lambda=0.0
# epoch 0 -- batchNb 10: 0.18848442 0.0 --  lambda=0.0
# epoch 0 -- batchNb 11: 0.1994563 0.0 --  lambda=0.0
# epoch 0 -- batchNb 12: 0.195489 0.0 --  lambda=0.0
# epoch 0 -- batchNb 13: 0.18709351 0.0 --  lambda=0.0
# epoch 0 -- batchNb 14: 0.18162951 0.0 --  lambda=0.0
# epoch 0 -- batchNb 15: 0.18039493 0.0 --  lambda=0.0
# epoch 0 -- batchNb 16: 0.18176772 0.0 --  lambda=0.0
# epoch 0 -- batchNb 17: 0.1836338 0.0 --  lambda=0.0
# epoch 0 -- batchNb 18: 0.17878646 0.0 --  lambda=0.0
# epoch 0 -- batchNb 19: 0.17516996 0.0 --  lambda=0.0
# epoch 0 -- batchNb 20: 0.17314905 0.0 --  lambda=0.0
# epoch 0 -- batchNb 21: 0.16869088 0.0 --  lambda=0.0
# epoch 0 -- batchNb 22: 0.16128129 0.0 --  lambda=0.0
# epoch 0 -- batchNb 23: 0.1664415 0.0 --  lambda=0.0
# epoch 0 -- batchNb 24: 0.1606388 0.0 --  lambda=0.0
# epoch 0 -- batchNb 25: 0.14569503 0.0 --  lambda=0.0
# epoch 0 -- batchNb 26: 0.14968918 0.0 --  lambda=0.0
# epoch 0 -- batchNb 27: 0.14887056 0.0 --  lambda=0.0
# epoch 0 -- batchNb 28: 0.15753813 0.0 --  lambda=0.0
# epoch 0 -- batchNb 29: 0.14187028 0.0 --  lambda=0.0
# epoch 0 -- batchNb 30: 0.14043333 0.0 --  lambda=0.0
# epoch 0 -- batchNb 31: 0.14580598 0.0 --  lambda=0.0
# epoch 0 -- batchNb 32: 0.13870473 0.0 --  lambda=0.0
# epoch 0 -- batchNb 33: 0.1409274 0.0 --  lambda=0.0
# epoch 0 -- batchNb 34: 0.15014535 0.0 --  lambda=0.0
# epoch 0 -- batchNb 35: 0.14055863 0.0 --  lambda=0.0
# epoch 0 -- batchNb 36: 0.142764 0.0 --  lambda=0.0
# epoch 0 -- batchNb 37: 0.13989978 0.0 --  lambda=0.0
# epoch 0 -- batchNb 38: 0.12967914 0.0 --  lambda=0.0
# epoch 0 -- batchNb 39: 0.14007516 0.0 --  lambda=0.0
# epoch 0 -- batchNb 40: 0.13931704 0.0 --  lambda=0.0
# epoch 0 -- batchNb 41: 0.1286137 0.0 --  lambda=0.0
# epoch 0 -- batchNb 42: 0.13587728 0.0 --  lambda=0.0
# epoch 0 -- batchNb 43: 0.11762621 0.0 --  lambda=0.0
# epoch 0 -- batchNb 44: 0.12921543 0.0 --  lambda=0.0
# epoch 0 -- batchNb 45: 0.12833299 0.0 --  lambda=0.0
# epoch 0 -- batchNb 46: 0.119723804 0.0 --  lambda=0.0
# epoch 0 -- batchNb 47: 0.12407154 0.0 --  lambda=0.0
# epoch 0 -- batchNb 48: 0.12097846 0.0 --  lambda=0.0
# epoch 0 -- batchNb 49: 0.12804966 0.0 --  lambda=0.0
# epoch 0 -- batchNb 50: 0.11510154 0.0 --  lambda=0.0
# epoch 0 -- batchNb 51: 0.12372248 0.0 --  lambda=0.0
# epoch 0 -- batchNb 52: 0.12314438 0.0 --  lambda=0.0
# epoch 0 -- batchNb 53: 0.12187208 0.0 --  lambda=0.0
# epoch 0 -- batchNb 54: 0.11250494 0.0 --  lambda=0.0
# epoch 0 -- batchNb 55: 0.116508655 0.0 --  lambda=0.0
# epoch 0 -- batchNb 56: 0.1213789 0.0 --  lambda=0.0
# epoch 0 -- batchNb 57: 0.118108585 0.0 --  lambda=0.0
# epoch 0 -- batchNb 58: 0.112825215 0.0 --  lambda=0.0
# epoch 0 -- batchNb 59: 0.122409925 0.0 --  lambda=0.0
# epoch 0 -- batchNb 60: 0.104169466 0.0 --  lambda=0.0
# epoch 0 -- batchNb 61: 0.10272206 0.0 --  lambda=0.0
# epoch 0 -- batchNb 62: 0.1147141 0.0 --  lambda=0.0
# epoch 0 -- batchNb 63: 0.11913252 0.0 --  lambda=0.0
# epoch 0 -- batchNb 64: 0.11284213 0.0 --  lambda=0.0
# epoch 0 -- batchNb 65: 0.1061645 0.0 --  lambda=0.0
# epoch 0 -- batchNb 66: 0.10947109 0.0 --  lambda=0.0
# epoch 0 -- batchNb 67: 0.10747066 0.0 --  lambda=0.0
# epoch 0 -- batchNb 68: 0.11028301 0.0 --  lambda=0.0
# epoch 0 -- batchNb 69: 0.11199381 0.0 --  lambda=0.0
# epoch 0 -- batchNb 70: 0.10560734 0.0 --  lambda=0.0
# epoch 0 -- batchNb 71: 0.10545842 0.0 --  lambda=0.0
# epoch 0 -- batchNb 72: 0.10806471 0.0 --  lambda=0.0
# epoch 0 -- batchNb 73: 0.11207178 0.0 --  lambda=0.0
# epoch 0 -- batchNb 74: 0.10160275 0.0 --  lambda=0.0
# epoch 0 -- batchNb 75: 0.10244955 0.0 --  lambda=0.0
# epoch 0 -- batchNb 76: 0.10459857 0.0 --  lambda=0.0
# epoch 0 -- batchNb 77: 0.11680776 0.0 --  lambda=0.0
# epoch 0 -- batchNb 78: 0.11300268 0.0 --  lambda=0.0
# epoch 0 -- batchNb 79: 0.098264255 0.0 --  lambda=0.0
# epoch 0 -- batchNb 80: 0.0953359 0.0 --  lambda=0.0
# epoch 0 -- batchNb 81: 0.09611587 0.0 --  lambda=0.0
# epoch 0 -- batchNb 82: 0.08720483 0.0 --  lambda=0.0
# epoch 0 -- batchNb 83: 0.103495724 0.0 --  lambda=0.0
# epoch 0 -- batchNb 84: 0.101886556 0.0 --  lambda=0.0
# epoch 0 -- batchNb 85: 0.09709371 0.0 --  lambda=0.0
# epoch 0 -- batchNb 86: 0.10275979 0.0 --  lambda=0.0
# epoch 0 -- batchNb 87: 0.10728516 0.0 --  lambda=0.0
# epoch 0 -- batchNb 88: 0.08976003 0.0 --  lambda=0.0
# epoch 0 -- batchNb 89: 0.093459934 0.0 --  lambda=0.0
# epoch 0 -- batchNb 90: 0.09586396 0.0 --  lambda=0.0
# epoch 0 -- batchNb 91: 0.09956401 0.0 --  lambda=0.0
# epoch 0 -- batchNb 92: 0.111300185 0.0 --  lambda=0.0
# epoch 0 -- batchNb 93: 0.0897271 0.0 --  lambda=0.0
# epoch 0 -- batchNb 94: 0.086147316 0.0 --  lambda=0.0
# epoch 0 -- batchNb 95: 0.10018233 0.0 --  lambda=0.0
# epoch 0 -- batchNb 96: 0.09763626 0.0 --  lambda=0.0
# epoch 1 -- batchNb 1: 0.09284392 0.0 --  lambda=0.0
# epoch 1 -- batchNb 2: 0.100060426 0.0 --  lambda=0.0
# epoch 1 -- batchNb 3: 0.09008823 0.0 --  lambda=0.0
# epoch 1 -- batchNb 4: 0.085360765 0.0 --  lambda=0.0
# epoch 1 -- batchNb 5: 0.0969429 0.0 --  lambda=0.0
# epoch 1 -- batchNb 6: 0.09583258 0.0 --  lambda=0.0
# epoch 1 -- batchNb 7: 0.089276515 0.0 --  lambda=0.0
# epoch 1 -- batchNb 8: 0.0931634 0.0 --  lambda=0.0
# epoch 1 -- batchNb 9: 0.09599599 0.0 --  lambda=0.0
# epoch 1 -- batchNb 10: 0.082776144 0.0 --  lambda=0.0
# epoch 1 -- batchNb 11: 0.09250288 0.0 --  lambda=0.0
# epoch 1 -- batchNb 12: 0.07928875 0.0 --  lambda=0.0
# epoch 1 -- batchNb 13: 0.09570602 0.0 --  lambda=0.0
# epoch 1 -- batchNb 14: 0.08933962 0.0 --  lambda=0.0
# epoch 1 -- batchNb 15: 0.08442767 0.0 --  lambda=0.0
# epoch 1 -- batchNb 16: 0.09429018 0.0 --  lambda=0.0
# epoch 1 -- batchNb 17: 0.09028606 0.0 --  lambda=0.0
# epoch 1 -- batchNb 18: 0.08460606 0.0 --  lambda=0.0
# epoch 1 -- batchNb 19: 0.081779346 0.0 --  lambda=0.0
# epoch 1 -- batchNb 20: 0.088158324 0.0 --  lambda=0.0
# epoch 1 -- batchNb 21: 0.08883612 0.0 --  lambda=0.0
# epoch 1 -- batchNb 22: 0.088384554 0.0 --  lambda=0.0
# epoch 1 -- batchNb 23: 0.08671485 0.0 --  lambda=0.0
# epoch 1 -- batchNb 24: 0.082766965 0.0 --  lambda=0.0
# epoch 1 -- batchNb 25: 0.07944074 0.0 --  lambda=0.0
# epoch 1 -- batchNb 26: 0.09359911 0.0 --  lambda=0.0
# epoch 1 -- batchNb 27: 0.09145474 0.0 --  lambda=0.0
# epoch 1 -- batchNb 28: 0.07613956 0.0 --  lambda=0.0
# epoch 1 -- batchNb 29: 0.09094875 0.0 --  lambda=0.0
# epoch 1 -- batchNb 30: 0.08355312 0.0 --  lambda=0.0
# epoch 1 -- batchNb 31: 0.08794722 0.0 --  lambda=0.0
# epoch 1 -- batchNb 32: 0.07989092 0.0 --  lambda=0.0
# epoch 1 -- batchNb 33: 0.07458955 0.0 --  lambda=0.0
# epoch 1 -- batchNb 34: 0.08138698 0.0 --  lambda=0.0
# epoch 1 -- batchNb 35: 0.07821142 0.0 --  lambda=0.0
# epoch 1 -- batchNb 36: 0.08553833 0.0 --  lambda=0.0
# epoch 1 -- batchNb 37: 0.074602395 0.0 --  lambda=0.0
# epoch 1 -- batchNb 38: 0.07005908 0.0 --  lambda=0.0
# epoch 1 -- batchNb 39: 0.08537053 0.0 --  lambda=0.0
# epoch 1 -- batchNb 40: 0.08721314 0.0 --  lambda=0.0
# epoch 1 -- batchNb 41: 0.08456333 0.0 --  lambda=0.0
# epoch 1 -- batchNb 42: 0.08805005 0.0 --  lambda=0.0
# epoch 1 -- batchNb 43: 0.078189135 0.0 --  lambda=0.0
# epoch 1 -- batchNb 44: 0.08385663 0.0 --  lambda=0.0
# epoch 1 -- batchNb 45: 0.07121882 0.0 --  lambda=0.0
# epoch 1 -- batchNb 46: 0.08964933 0.0 --  lambda=0.0
# epoch 1 -- batchNb 47: 0.0734758 0.0 --  lambda=0.0
# epoch 1 -- batchNb 48: 0.0761522 0.0 --  lambda=0.0
# epoch 1 -- batchNb 49: 0.07913875 0.0 --  lambda=0.0
# epoch 1 -- batchNb 50: 0.07638744 0.0 --  lambda=0.0
# epoch 1 -- batchNb 51: 0.07965195 0.0 --  lambda=0.0
# epoch 1 -- batchNb 52: 0.08415374 0.0 --  lambda=0.0
# epoch 1 -- batchNb 53: 0.07661676 0.0 --  lambda=0.0
# epoch 1 -- batchNb 54: 0.077777326 0.0 --  lambda=0.0
# epoch 1 -- batchNb 55: 0.087762445 0.0 --  lambda=0.0
# epoch 1 -- batchNb 56: 0.074384764 0.0 --  lambda=0.0
# epoch 1 -- batchNb 57: 0.07532722 0.0 --  lambda=0.0
# epoch 1 -- batchNb 58: 0.0702584 0.0 --  lambda=0.0
# epoch 1 -- batchNb 59: 0.08598501 0.0 --  lambda=0.0
# epoch 1 -- batchNb 60: 0.07541024 0.0 --  lambda=0.0
# epoch 1 -- batchNb 61: 0.062489282 0.0 --  lambda=0.0
# epoch 1 -- batchNb 62: 0.07820827 0.0 --  lambda=0.0
# epoch 1 -- batchNb 63: 0.07141414 0.0 --  lambda=0.0
# epoch 1 -- batchNb 64: 0.0787124 0.0 --  lambda=0.0
# epoch 1 -- batchNb 65: 0.0745047 0.0 --  lambda=0.0
# epoch 1 -- batchNb 66: 0.06752541 0.0 --  lambda=0.0
# epoch 1 -- batchNb 67: 0.061364364 0.0 --  lambda=0.0
# epoch 1 -- batchNb 68: 0.06476524 0.0 --  lambda=0.0
# epoch 1 -- batchNb 69: 0.08200842 0.0 --  lambda=0.0
# epoch 1 -- batchNb 70: 0.06968128 0.0 --  lambda=0.0
# epoch 1 -- batchNb 71: 0.06817926 0.0 --  lambda=0.0
# epoch 1 -- batchNb 72: 0.0779993 0.0 --  lambda=0.0
# epoch 1 -- batchNb 73: 0.07833276 0.0 --  lambda=0.0
# epoch 1 -- batchNb 74: 0.07647986 0.0 --  lambda=0.0
# epoch 1 -- batchNb 75: 0.076948784 0.0 --  lambda=0.0
# epoch 1 -- batchNb 76: 0.078791626 0.0 --  lambda=0.0
# epoch 1 -- batchNb 77: 0.06808751 0.0 --  lambda=0.0
# epoch 1 -- batchNb 78: 0.05482706 0.0 --  lambda=0.0
# epoch 1 -- batchNb 79: 0.06540178 0.0 --  lambda=0.0
# epoch 1 -- batchNb 80: 0.073408164 0.0 --  lambda=0.0
# epoch 1 -- batchNb 81: 0.082045086 0.0 --  lambda=0.0
# epoch 1 -- batchNb 82: 0.08273543 0.0 --  lambda=0.0
# epoch 1 -- batchNb 83: 0.07709368 0.0 --  lambda=0.0
# epoch 1 -- batchNb 84: 0.082453124 0.0 --  lambda=0.0
# epoch 1 -- batchNb 85: 0.08805935 0.0 --  lambda=0.0
# epoch 1 -- batchNb 86: 0.080104835 0.0 --  lambda=0.0
# epoch 1 -- batchNb 87: 0.0680825 0.0 --  lambda=0.0
# epoch 1 -- batchNb 88: 0.07559511 0.0 --  lambda=0.0
# epoch 1 -- batchNb 89: 0.08465573 0.0 --  lambda=0.0
# epoch 1 -- batchNb 90: 0.06612559 0.0 --  lambda=0.0
# epoch 1 -- batchNb 91: 0.066251695 0.0 --  lambda=0.0
# epoch 1 -- batchNb 92: 0.069450304 0.0 --  lambda=0.0
# epoch 1 -- batchNb 93: 0.076214805 0.0 --  lambda=0.0
# epoch 1 -- batchNb 94: 0.067242935 0.0 --  lambda=0.0
# epoch 1 -- batchNb 95: 0.08067508 0.0 --  lambda=0.0
# epoch 1 -- batchNb 96: 0.08922874 0.0 --  lambda=0.0
# epoch 2 -- batchNb 1: 0.06598549 0.0 --  lambda=0.0
# epoch 2 -- batchNb 2: 0.07707887 0.0 --  lambda=0.0
# epoch 2 -- batchNb 3: 0.07058042 0.0 --  lambda=0.0
# epoch 2 -- batchNb 4: 0.074777514 0.0 --  lambda=0.0
# epoch 2 -- batchNb 5: 0.07310552 0.0 --  lambda=0.0
# epoch 2 -- batchNb 6: 0.072916925 0.0 --  lambda=0.0
# epoch 2 -- batchNb 7: 0.07373879 0.0 --  lambda=0.0
# epoch 2 -- batchNb 8: 0.066577025 0.0 --  lambda=0.0
# epoch 2 -- batchNb 9: 0.069454424 0.0 --  lambda=0.0
# epoch 2 -- batchNb 10: 0.066714875 0.0 --  lambda=0.0
# epoch 2 -- batchNb 11: 0.07191194 0.0 --  lambda=0.0
# epoch 2 -- batchNb 12: 0.061676603 0.0 --  lambda=0.0
# epoch 2 -- batchNb 13: 0.069288746 0.0 --  lambda=0.0
# epoch 2 -- batchNb 14: 0.071061224 0.0 --  lambda=0.0
# epoch 2 -- batchNb 15: 0.06770106 0.0 --  lambda=0.0
# epoch 2 -- batchNb 16: 0.06555178 0.0 --  lambda=0.0
# epoch 2 -- batchNb 17: 0.06582713 0.0 --  lambda=0.0
# epoch 2 -- batchNb 18: 0.06686515 0.0 --  lambda=0.0
# epoch 2 -- batchNb 19: 0.062303416 0.0 --  lambda=0.0
# epoch 2 -- batchNb 20: 0.06845622 0.0 --  lambda=0.0
# epoch 2 -- batchNb 21: 0.06556241 0.0 --  lambda=0.0
# epoch 2 -- batchNb 22: 0.055897094 0.0 --  lambda=0.0
# epoch 2 -- batchNb 23: 0.0626001 0.0 --  lambda=0.0
# epoch 2 -- batchNb 24: 0.062457465 0.0 --  lambda=0.0
# epoch 2 -- batchNb 25: 0.06720803 0.0 --  lambda=0.0
# epoch 2 -- batchNb 26: 0.06923617 0.0 --  lambda=0.0
# epoch 2 -- batchNb 27: 0.064961165 0.0 --  lambda=0.0
# epoch 2 -- batchNb 28: 0.061371192 0.0 --  lambda=0.0
# epoch 2 -- batchNb 29: 0.06360748 0.0 --  lambda=0.0
# epoch 2 -- batchNb 30: 0.0661479 0.0 --  lambda=0.0
# epoch 2 -- batchNb 31: 0.06390505 0.0 --  lambda=0.0
# epoch 2 -- batchNb 32: 0.057283796 0.0 --  lambda=0.0
# epoch 3 -- batchNb 1: 0.07094302 0.0 --  lambda=0.0
# epoch 3 -- batchNb 2: 0.06019727 0.0 --  lambda=0.0
# epoch 3 -- batchNb 3: 0.060198136 0.0 --  lambda=0.0
# epoch 3 -- batchNb 4: 0.051999673 0.0 --  lambda=0.0
# epoch 3 -- batchNb 5: 0.071661115 0.0 --  lambda=0.0
# epoch 3 -- batchNb 6: 0.050477836 0.0 --  lambda=0.0
# epoch 3 -- batchNb 7: 0.057035375 0.0 --  lambda=0.0
# epoch 3 -- batchNb 8: 0.05880552 0.0 --  lambda=0.0
# epoch 3 -- batchNb 9: 0.061032817 0.0 --  lambda=0.0
# epoch 3 -- batchNb 10: 0.060240433 0.0 --  lambda=0.0
# epoch 3 -- batchNb 11: 0.06099106 0.0 --  lambda=0.0
# epoch 3 -- batchNb 12: 0.058615062 0.0 --  lambda=0.0
# epoch 3 -- batchNb 13: 0.07113455 0.0 --  lambda=0.0
# epoch 3 -- batchNb 14: 0.0606079 0.0 --  lambda=0.0
# epoch 3 -- batchNb 15: 0.06448787 0.0 --  lambda=0.0
# epoch 3 -- batchNb 16: 0.058633212 0.0 --  lambda=0.0
# epoch 3 -- batchNb 17: 0.069395654 0.0 --  lambda=0.0
# epoch 3 -- batchNb 18: 0.056707177 0.0 --  lambda=0.0
# epoch 3 -- batchNb 19: 0.05170585 0.0 --  lambda=0.0
# epoch 3 -- batchNb 20: 0.054467652 0.0 --  lambda=0.0
# epoch 3 -- batchNb 21: 0.06213326 0.0 --  lambda=0.0
# epoch 3 -- batchNb 22: 0.05745512 0.0 --  lambda=0.0
# epoch 3 -- batchNb 23: 0.058226794 0.0 --  lambda=0.0
# epoch 3 -- batchNb 24: 0.05854428 0.0 --  lambda=0.0
# epoch 3 -- batchNb 25: 0.055346083 0.0 --  lambda=0.0
# epoch 3 -- batchNb 26: 0.059427585 0.0 --  lambda=0.0
# epoch 3 -- batchNb 27: 0.054945525 0.0 --  lambda=0.0
# epoch 3 -- batchNb 28: 0.056770332 0.0 --  lambda=0.0
# epoch 3 -- batchNb 29: 0.062260557 0.0 --  lambda=0.0
# epoch 3 -- batchNb 30: 0.0573975 0.0 --  lambda=0.0
# epoch 3 -- batchNb 31: 0.056590125 0.0 --  lambda=0.0
# epoch 3 -- batchNb 32: 0.057828777 0.0 --  lambda=0.0
# epoch 4 -- batchNb 1: 0.053356133 0.0 --  lambda=0.0
# epoch 4 -- batchNb 2: 0.05326359 0.0 --  lambda=0.0
# epoch 4 -- batchNb 3: 0.060244884 0.0 --  lambda=0.0
# epoch 4 -- batchNb 4: 0.05421579 0.0 --  lambda=0.0
# epoch 4 -- batchNb 5: 0.058778826 0.0 --  lambda=0.0
# epoch 4 -- batchNb 6: 0.053143512 0.0 --  lambda=0.0
# epoch 4 -- batchNb 7: 0.058099963 0.0 --  lambda=0.0
# epoch 4 -- batchNb 8: 0.054185092 0.0 --  lambda=0.0
# epoch 4 -- batchNb 9: 0.059169464 0.0 --  lambda=0.0
# epoch 4 -- batchNb 10: 0.052423097 0.0 --  lambda=0.0
# epoch 4 -- batchNb 11: 0.05151792 0.0 --  lambda=0.0
# epoch 4 -- batchNb 12: 0.056202117 0.0 --  lambda=0.0
# epoch 4 -- batchNb 13: 0.05794383 0.0 --  lambda=0.0
# epoch 4 -- batchNb 14: 0.049879715 0.0 --  lambda=0.0
# epoch 4 -- batchNb 15: 0.0581609 0.0 --  lambda=0.0
# epoch 4 -- batchNb 16: 0.054735724 0.0 --  lambda=0.0
# Run training - with reg
# epoch 0 -- batchNb 1: 0.25650632 0.00018328432465078797 --  lambda=0.0005
# epoch 0 -- batchNb 2: 0.25196582 0.0005188879524914265 --  lambda=0.0005
# epoch 0 -- batchNb 3: 0.24897139 0.0002476843567224801 --  lambda=0.0005
# epoch 0 -- batchNb 4: 0.2427522 0.00025258636410361755 --  lambda=0.0005
# epoch 0 -- batchNb 5: 0.23880798 0.00042824795367142317 --  lambda=0.0005
# epoch 0 -- batchNb 6: 0.23257546 0.0011462548185920698 --  lambda=0.0005
# epoch 0 -- batchNb 7: 0.22761174 0.001099299552519791 --  lambda=0.0005
# epoch 0 -- batchNb 8: 0.22326802 0.00185188247505854 --  lambda=0.0005
# epoch 0 -- batchNb 9: 0.21534976 0.0032904971675331448 --  lambda=0.0005
# epoch 0 -- batchNb 10: 0.2227683 0.002791788500684485 --  lambda=0.0005
# epoch 0 -- batchNb 11: 0.21180187 0.007003689639802045 --  lambda=0.0005
# epoch 0 -- batchNb 12: 0.21135487 0.0044052788850003155 --  lambda=0.0005
# epoch 0 -- batchNb 13: 0.20038266 0.004993109299694949 --  lambda=0.0005
# epoch 0 -- batchNb 14: 0.19746044 0.007076771357437269 --  lambda=0.0005
# epoch 0 -- batchNb 15: 0.19910997 0.006860075096655915 --  lambda=0.0005
# epoch 0 -- batchNb 16: 0.1991425 0.005648780050677269 --  lambda=0.0005
# epoch 0 -- batchNb 17: 0.18781205 0.008091049543981408 --  lambda=0.0005
# epoch 0 -- batchNb 18: 0.19779885 0.018311171141590858 --  lambda=0.0005
# epoch 0 -- batchNb 19: 0.18259566 0.010447257966133874 --  lambda=0.0005
# epoch 0 -- batchNb 20: 0.17280272 0.014176397466194922 --  lambda=0.0005
# epoch 0 -- batchNb 21: 0.18606701 0.009439848975554777 --  lambda=0.0005
# epoch 0 -- batchNb 22: 0.17788859 0.02226227617548554 --  lambda=0.0005
# epoch 0 -- batchNb 23: 0.1774831 0.014010622446171864 --  lambda=0.0005
# epoch 0 -- batchNb 24: 0.1733025 0.02177335901899709 --  lambda=0.0005
# epoch 0 -- batchNb 25: 0.17184453 0.0176933731445189 --  lambda=0.0005
# epoch 0 -- batchNb 26: 0.1583542 0.04028358347414186 --  lambda=0.0005
# epoch 0 -- batchNb 27: 0.16015494 0.024949587112961635 --  lambda=0.0005
# epoch 0 -- batchNb 28: 0.16118991 0.028611078024689388 --  lambda=0.0005
# epoch 0 -- batchNb 29: 0.16978289 0.031094741043615037 --  lambda=0.0005
# epoch 0 -- batchNb 30: 0.15828538 0.049111227735903 --  lambda=0.0005
# epoch 0 -- batchNb 31: 0.15423433 0.027623753425022896 --  lambda=0.0005
# epoch 0 -- batchNb 32: 0.16574292 0.03947963026896067 --  lambda=0.0005
# epoch 0 -- batchNb 33: 0.14633505 0.017179494368996566 --  lambda=0.0005
# epoch 0 -- batchNb 34: 0.15199816 0.04762354403357642 --  lambda=0.0005
# epoch 0 -- batchNb 35: 0.15694572 0.055431885504022185 --  lambda=0.0005
# epoch 0 -- batchNb 36: 0.1469386 0.03832645755966121 --  lambda=0.0005
# epoch 0 -- batchNb 37: 0.14305566 0.04636527759826407 --  lambda=0.0005
# epoch 0 -- batchNb 38: 0.15225594 0.05321670535934136 --  lambda=0.0005
# epoch 0 -- batchNb 39: 0.13970308 0.04313266664692023 --  lambda=0.0005
# epoch 0 -- batchNb 40: 0.15339944 0.04614082964325143 --  lambda=0.0005
# epoch 0 -- batchNb 41: 0.13845694 0.03292803944951411 --  lambda=0.0005
# epoch 0 -- batchNb 42: 0.15072085 0.06322920427524845 --  lambda=0.0005
# epoch 0 -- batchNb 43: 0.1399736 0.027920581087448406 --  lambda=0.0005
# epoch 0 -- batchNb 44: 0.13191657 0.04887681318907669 --  lambda=0.0005
# epoch 0 -- batchNb 45: 0.13606693 0.0613924582881666 --  lambda=0.0005
# epoch 0 -- batchNb 46: 0.14869814 0.05644606588738392 --  lambda=0.0005
# epoch 0 -- batchNb 47: 0.13201146 0.03537384260970289 --  lambda=0.0005
# epoch 0 -- batchNb 48: 0.14909883 0.057605364079345855 --  lambda=0.0005
# epoch 0 -- batchNb 49: 0.14290784 0.05119220173013241 --  lambda=0.0005
# epoch 0 -- batchNb 50: 0.13191633 0.054850708686739295 --  lambda=0.0005
# epoch 0 -- batchNb 51: 0.13133453 0.053816013441499534 --  lambda=0.0005
# epoch 0 -- batchNb 52: 0.13678946 0.051978130913951606 --  lambda=0.0005
# epoch 0 -- batchNb 53: 0.12919545 0.0518130926842276 --  lambda=0.0005
# epoch 0 -- batchNb 54: 0.12780789 0.05701067371557424 --  lambda=0.0005
# epoch 0 -- batchNb 55: 0.117641546 0.06621770833364171 --  lambda=0.0005
# epoch 0 -- batchNb 56: 0.12688354 0.05994807987118526 --  lambda=0.0005
# epoch 0 -- batchNb 57: 0.13085099 0.0737468335669245 --  lambda=0.0005
# epoch 0 -- batchNb 58: 0.1330162 0.0528196528106741 --  lambda=0.0005
# epoch 0 -- batchNb 59: 0.13930292 0.07097661164262031 --  lambda=0.0005
# epoch 0 -- batchNb 60: 0.12885426 0.08338513895515348 --  lambda=0.0005
# epoch 0 -- batchNb 61: 0.132794 0.05438801808364718 --  lambda=0.0005
# epoch 0 -- batchNb 62: 0.1136482 0.06971064703964049 --  lambda=0.0005
# epoch 0 -- batchNb 63: 0.12623052 0.08944716842709174 --  lambda=0.0005
# epoch 0 -- batchNb 64: 0.1264932 0.07944252159037468 --  lambda=0.0005
# epoch 0 -- batchNb 65: 0.12752815 0.08235607553037481 --  lambda=0.0005
# epoch 0 -- batchNb 66: 0.122464664 0.08435389472373309 --  lambda=0.0005
# epoch 0 -- batchNb 67: 0.1222089 0.09958115168257776 --  lambda=0.0005
# epoch 0 -- batchNb 68: 0.13717043 0.0896796717452681 --  lambda=0.0005
# epoch 0 -- batchNb 69: 0.12267923 0.06955466896279056 --  lambda=0.0005
# epoch 0 -- batchNb 70: 0.11725129 0.06471862425013611 --  lambda=0.0005
# epoch 0 -- batchNb 71: 0.122142784 0.13222902642733986 --  lambda=0.0005
# epoch 0 -- batchNb 72: 0.11609768 0.0808007947553629 --  lambda=0.0005
# epoch 0 -- batchNb 73: 0.12209797 0.07447752115707731 --  lambda=0.0005
# epoch 0 -- batchNb 74: 0.10747673 0.09933612341415803 --  lambda=0.0005
# epoch 0 -- batchNb 75: 0.123168394 0.07937658954647947 --  lambda=0.0005
# epoch 0 -- batchNb 76: 0.10777088 0.1171010429343876 --  lambda=0.0005
# epoch 0 -- batchNb 77: 0.11888788 0.09152867295668365 --  lambda=0.0005
# epoch 0 -- batchNb 78: 0.1102723 0.07967699585271033 --  lambda=0.0005
# epoch 0 -- batchNb 79: 0.11594697 0.058354565997988224 --  lambda=0.0005
# epoch 0 -- batchNb 80: 0.12302871 0.06796182787984745 --  lambda=0.0005
# epoch 0 -- batchNb 81: 0.11466153 0.06973664883626675 --  lambda=0.0005
# epoch 0 -- batchNb 82: 0.1169705 0.07957513823759611 --  lambda=0.0005
# epoch 0 -- batchNb 83: 0.12733151 0.09997240630674599 --  lambda=0.0005
# epoch 0 -- batchNb 84: 0.1235935 0.06588859756229176 --  lambda=0.0005
# epoch 0 -- batchNb 85: 0.12118029 0.08501356626648304 --  lambda=0.0005
# epoch 0 -- batchNb 86: 0.11417682 0.10782780948459185 --  lambda=0.0005
# epoch 0 -- batchNb 87: 0.10987984 0.12652377276063856 --  lambda=0.0005
# epoch 0 -- batchNb 88: 0.1075107 0.09553362462923759 --  lambda=0.0005
# epoch 0 -- batchNb 89: 0.11700106 0.08264870531786064 --  lambda=0.0005
# epoch 0 -- batchNb 90: 0.13533114 0.07082947593684319 --  lambda=0.0005
# epoch 0 -- batchNb 91: 0.11545797 0.09256301276770763 --  lambda=0.0005
# epoch 0 -- batchNb 92: 0.12820415 0.07254974894702242 --  lambda=0.0005
# epoch 0 -- batchNb 93: 0.11863854 0.11448971959045058 --  lambda=0.0005
# epoch 0 -- batchNb 94: 0.11238573 0.07693910934008882 --  lambda=0.0005
# epoch 0 -- batchNb 95: 0.116932586 0.07854226876150927 --  lambda=0.0005
# epoch 0 -- batchNb 96: 0.107772 0.11185873951236751 --  lambda=0.0005
# epoch 1 -- batchNb 1: 0.10637249 0.07759017503656851 --  lambda=0.0005
# epoch 2 -- batchNb 14: 0.10198994 0.10959484809071873 --  lambda=0.0005
# epoch 2 -- batchNb 15: 0.101148635 0.09208044228713652 --  lambda=0.0005
# epoch 2 -- batchNb 16: 0.099531196 0.12476086155347703 --  lambda=0.0005
# epoch 2 -- batchNb 17: 0.10146426 0.10226916943369728 --  lambda=0.0005
# epoch 2 -- batchNb 18: 0.1009096 0.11042763857866417 --  lambda=0.0005
# epoch 2 -- batchNb 19: 0.10506168 0.0716980178427063 --  lambda=0.0005
# epoch 2 -- batchNb 20: 0.10448313 0.09046121959505588 --  lambda=0.0005
# epoch 2 -- batchNb 21: 0.10394605 0.12419569928754277 --  lambda=0.0005
# epoch 2 -- batchNb 22: 0.09451177 0.15981242915466945 --  lambda=0.0005
# epoch 2 -- batchNb 23: 0.10597315 0.09827027461525367 --  lambda=0.0005
# epoch 2 -- batchNb 24: 0.10973785 0.1342682407132595 --  lambda=0.0005
# epoch 2 -- batchNb 25: 0.102721415 0.09619271760717443 --  lambda=0.0005
# epoch 2 -- batchNb 26: 0.102063954 0.09538265090678438 --  lambda=0.0005
# epoch 2 -- batchNb 27: 0.10056592 0.11291613422210295 --  lambda=0.0005
# epoch 2 -- batchNb 28: 0.10315945 0.10698316411140002 --  lambda=0.0005
# epoch 2 -- batchNb 29: 0.10042017 0.10513898458635942 --  lambda=0.0005
# epoch 2 -- batchNb 30: 0.0998642 0.11470540868782313 --  lambda=0.0005
# epoch 2 -- batchNb 31: 0.10977543 0.10677957797013188 --  lambda=0.0005
# epoch 2 -- batchNb 32: 0.0990534 0.1253975053302113 --  lambda=0.0005
# epoch 3 -- batchNb 1: 0.103027835 0.15343820409339043 --  lambda=0.0005
# epoch 3 -- batchNb 2: 0.099373765 0.07818961314308838 --  lambda=0.0005
# epoch 3 -- batchNb 3: 0.10303548 0.06968828305012033 --  lambda=0.0005
# epoch 3 -- batchNb 4: 0.1000581 0.1202981086524155 --  lambda=0.0005
# epoch 3 -- batchNb 5: 0.10454757 0.15553552469197104 --  lambda=0.0005
# epoch 3 -- batchNb 6: 0.102055624 0.15306253993701127 --  lambda=0.0005
# epoch 3 -- batchNb 7: 0.10125006 0.09971605666359505 --  lambda=0.0005
# epoch 3 -- batchNb 8: 0.10250623 0.14725157806649944 --  lambda=0.0005
# epoch 3 -- batchNb 9: 0.10172075 0.1328399239307856 --  lambda=0.0005
# epoch 3 -- batchNb 10: 0.10509619 0.10890964390517009 --  lambda=0.0005
# epoch 3 -- batchNb 11: 0.0972709 0.0781779705724305 --  lambda=0.0005
# epoch 3 -- batchNb 12: 0.097570114 0.10875194241090519 --  lambda=0.0005
# epoch 3 -- batchNb 13: 0.09866855 0.14178939703377508 --  lambda=0.0005
# epoch 3 -- batchNb 14: 0.0968563 0.07159844233848536 --  lambda=0.0005
# epoch 3 -- batchNb 15: 0.10437177 0.100911524554394 --  lambda=0.0005
# epoch 3 -- batchNb 16: 0.09799863 0.11732593739235886 --  lambda=0.0005
# epoch 3 -- batchNb 17: 0.0971385 0.10400505529483729 --  lambda=0.0005
# epoch 3 -- batchNb 18: 0.09650151 0.09007456840108084 --  lambda=0.0005
# epoch 3 -- batchNb 19: 0.10053122 0.12168422632517359 --  lambda=0.0005
# epoch 3 -- batchNb 20: 0.09894203 0.10105425415906062 --  lambda=0.0005
# epoch 3 -- batchNb 21: 0.09333504 0.1271519963229765 --  lambda=0.0005
# epoch 3 -- batchNb 22: 0.10175134 0.09288445486867088 --  lambda=0.0005
# epoch 3 -- batchNb 23: 0.09764909 0.07341728929034434 --  lambda=0.0005
# epoch 3 -- batchNb 24: 0.09730634 0.1439274957899354 --  lambda=0.0005
# epoch 3 -- batchNb 25: 0.09797376 0.07395950288491157 --  lambda=0.0005
# epoch 3 -- batchNb 26: 0.097663365 0.15797427906474576 --  lambda=0.0005
# epoch 3 -- batchNb 27: 0.09504258 0.14270535419274763 --  lambda=0.0005
# epoch 3 -- batchNb 28: 0.09710579 0.15603269631865885 --  lambda=0.0005
# epoch 3 -- batchNb 29: 0.09756914 0.10937024955411219 --  lambda=0.0005
# epoch 3 -- batchNb 30: 0.097695336 0.12629763695713833 --  lambda=0.0005
# epoch 3 -- batchNb 31: 0.097273536 0.1257970717333839 --  lambda=0.0005
# epoch 3 -- batchNb 32: 0.10145971 0.10888422281741339 --  lambda=0.0005
# epoch 4 -- batchNb 1: 0.095521726 0.1388064433065463 --  lambda=0.0005
# epoch 4 -- batchNb 2: 0.09716528 0.10914056806014073 --  lambda=0.0005
# epoch 4 -- batchNb 3: 0.096649505 0.14427408576157932 --  lambda=0.0005
# epoch 4 -- batchNb 4: 0.0963873 0.13090474579665587 --  lambda=0.0005
# epoch 4 -- batchNb 5: 0.09905133 0.07532722450037946 --  lambda=0.0005
# epoch 4 -- batchNb 6: 0.09895127 0.1484521507524841 --  lambda=0.0005
# epoch 4 -- batchNb 7: 0.09931857 0.08712589811606819 --  lambda=0.0005
# epoch 4 -- batchNb 8: 0.09833702 0.16131867396232366 --  lambda=0.0005
# epoch 4 -- batchNb 9: 0.10309871 0.07466600894167447 --  lambda=0.0005
# epoch 4 -- batchNb 10: 0.10107416 0.12832450839367016 --  lambda=0.0005
# epoch 4 -- batchNb 11: 0.100063704 0.14924386597163197 --  lambda=0.0005
# epoch 4 -- batchNb 12: 0.10239568 0.09031448588374522 --  lambda=0.0005
# epoch 4 -- batchNb 13: 0.102821305 0.10481565180767914 --  lambda=0.0005
# epoch 4 -- batchNb 14: 0.1012746 0.12804123261280825 --  lambda=0.0005
# epoch 4 -- batchNb 15: 0.097782746 0.11064630684001205 --  lambda=0.0005
# epoch 4 -- batchNb 16: 0.1003393 0.08768619473965804 --  lambda=0.0005

# %% [markdown]
# **Tests - with regularisation**

# %%
predY_nogen_test=torch.clone(W2Rcore.LargeDatasetPred(model_no_reg_nogen,X_bw_nogen_test.float(),10000,DEVICE=DEVICE))  #prediction made with blocks of 10000 observations to make sure we won't saturate the memory
    
error = nn.MSELoss()  #does not take into account the W2 metric

loss = error(predY_nogen_test, Titles_test.float())
    
tmp_loss=loss.data
print('Loss (test data): '+str(tmp_loss))
            
y_pred_nogen_np=1*(predY_nogen_test.view(-1).data.numpy()>0.5)
y_true_np=1*(Titles_test.view(-1).data.numpy()>0.5)
S_np=Gen_test[:]
    
tmp_DI=W2Rmisc.compute_disparate_impact(y_pred_nogen_np, S_np)
print('DI:',tmp_DI)
    
tmp_cm=W2Rmisc.cpt_BasicDescrStats(y_pred_nogen_np, y_true_np, S_np)
print(tmp_cm)   
print('s0_RatioGoodPred:',tmp_cm['s0_RatioGoodPred'])
print('s1_RatioGoodPred:',tmp_cm['s1_RatioGoodPred'])

mse = sum((y_pred_nogen_np-y_true_np)**2) / len(y_true_np)
print("MSE :",mse)

Accuracy=accuracy_score(y_true_np, y_pred_nogen_np)

y_pred_nogen_torch=torch.FloatTensor(y_pred_nogen_np)
y_pred_nogen_torch=y_pred_torch.reshape(y_pred_nogen_torch.shape[0],1)
y_true_torch=torch.FloatTensor(y_true_np)
y_true_torch=y_pred_torch.reshape(y_true_torch.shape[0],1)

result=W2Rcore.EstimGrad_W2dist(Gen_test,y_pred_nogen_torch,y_true_torch,Gen_test,y_pred_nogen_torch,y_true_torch, NbBins=500,ID_TreatedVar=0,DistBetween='All predictions',show_histos=True)
W_score=result[1]
# Out:
# Loss (test data): tensor(0.2178)
# DI: 0.44562230298388256
# {'s0_total': 5265.0, 's0_TP': 0.6778115501519757, 's0_FP': 0.19730844367267203, 's0_TN': 0.802691556327328, 's0_FN': 0.3221884498480243, 's0_RatioGoodPred': 0.7870845204178537, 's1_total': 7610.0, 's1_TP': 0.6344969199178645, 's1_FP': 0.08712121212121213, 's1_TN': 0.9128787878787878, 's1_FN': 0.3655030800821355, 's1_RatioGoodPred': 0.6634691195795006}
# s0_RatioGoodPred: 0.7870845204178537
# s1_RatioGoodPred: 0.6634691195795006
# MSE : 0.28598058252427183

# %% [markdown]
# **Tests - without regularisation**

# %%
predY_test=torch.clone(W2Rcore.LargeDatasetPred(model_reg_nogen,X_bw_nogen_test.float(),10000,DEVICE=DEVICE))  #prediction made with blocks of 10000 observations to make sure we won't saturate the memory
    
error = nn.MSELoss()  #does not take into account the W2 metric
loss = error(predY_test, Titles_test.float())
    
tmp_loss=loss.data #fonction coût, loss est un scalaire elle doit tendre vers 0
print('Loss (test data): '+str(tmp_loss))
            
y_pred_np=1*(predY_test.view(-1).data.numpy()>0.5)
y_true_np=1*(Titles_test.view(-1).data.numpy()>0.5)
S_np=Gen_test[:]
    
tmp_DI_r=W2Rmisc.compute_disparate_impact(y_pred_np, S_np)
print('DI:',tmp_DI_r) #DI = disparate_impact
    
tmp_cm_r=W2Rmisc.cpt_BasicDescrStats(y_pred_np, y_true_np, S_np)
#print(tmp_cm)  
print('s0_RatioGoodPred:',tmp_cm_r['s0_RatioGoodPred'])
print('s1_RatioGoodPred:',tmp_cm_r['s1_RatioGoodPred'])


mse_r = sum((y_pred_np-y_true_np)**2) / len(y_true_np)
print("MSE :",mse)

Accuracy_r=accuracy_score(y_true_np, y_pred_np)

y_pred_torch=torch.FloatTensor(y_pred_np)
y_pred_torch=y_pred_torch.reshape(y_pred_torch.shape[0],1)
y_true_torch=torch.FloatTensor(y_true_np)
y_true_torch=y_pred_torch.reshape(y_true_torch.shape[0],1)

result=W2Rcore.EstimGrad_W2dist(Gen_test,y_pred_torch,y_true_torch,Gen_test,y_pred_torch,y_true_torch, NbBins=500,ID_TreatedVar=0,DistBetween='All predictions')
W_score_r=result[1]
# Out:
# Loss (test data): tensor(0.2157)
# DI: 0.3287736878085331
# s0_RatioGoodPred: 0.8558404558404559
# s1_RatioGoodPred: 0.6559789750328515
# MSE : 0.28598058252427183

# %%
#lambda_nogen=[]
#lambda_nogen_r=[]
#DI_nogen=[]
#DI_nogen_r=[]
#MSE_nogen=[]
#MSE_nogen_r=[]
#s0RGP_nogen=[]
#s1RGP_nogen=[]
#s0RGP_nogen_r=[]
#s1RGP_nogen_r=[]
#accuracy_nogen=[]
#accuracy_nogen_r=[]
#W_nogen=[]
#W_nogen_r=[]

# %%
lambda_nogen.append(lambdavar)
lambda_nogen_r.append(lambdavar_r)

DI_nogen.append(tmp_DI)
DI_nogen_r.append(tmp_DI_r)

MSE_nogen.append(mse)
MSE_nogen_r.append(mse_r)

s0RGP_nogen.append(tmp_cm['s0_RatioGoodPred'])
s1RGP_nogen.append(tmp_cm['s1_RatioGoodPred']) 

s0RGP_nogen_r.append(tmp_cm_r['s0_RatioGoodPred'])
s1RGP_nogen_r.append(tmp_cm_r['s1_RatioGoodPred'])

W_nogen.append(W_score)
W_nogen_r.append(W_score_r)

accuracy_nogen.append(Accuracy)
accuracy_nogen_r.append(Accuracy_r)

# %% [markdown]
# ## Visualization

# %%
#Accuracy
plt.figure()
plt.scatter(lambda_nogen, accuracy_nogen, color='blue')
plt.scatter(lambda_nogen_r, accuracy_nogen_r, color='blue')
plt.xlabel('lambda')
plt.ylabel('précision')
plt.title("Accuracy nogen")
plt.savefig('Accuracy_nogen_reg.pdf')

#DI
plt.figure()
plt.scatter(lambda_nogen, DI_nogen, color='blue')
plt.scatter(lambda_nogen_r, DI_nogen_r, color='blue')
plt.xlabel('lambda')
plt.title("DI nogen")
plt.savefig('DI_nogen_reg.pdf')

#MSE
plt.figure()
plt.scatter(lambda_nogen, MSE_nogen, color='blue')
plt.scatter(lambda_nogen_r, MSE_nogen_r, color='blue')
plt.xlabel('lambda')
plt.title("MSE nogen")
plt.savefig('MSE_nogen_reg.pdf')

#Ratio good pred
plt.figure()
plt.scatter(lambda_nogen, s1RGP_nogen, label="s1", color='red')
plt.scatter(lambda_nogen, s0RGP_nogen, label="s0", color='blue')
plt.scatter(lambda_nogen_r, s0RGP_nogen_r, color='blue')
plt.scatter(lambda_nogen_r, s1RGP_nogen_r, color='red')
plt.xlabel('lambda')
plt.title("RatioGoodPred nogen")
plt.legend()
plt.savefig('RatioGoodPred_nogen_reg.pdf')

#W score
plt.figure()
plt.scatter(lambda_nogen, W_nogen, color='blue')
plt.scatter(lambda_nogen_r, W_nogen_r, color='blue')
plt.xlabel('lambda')
plt.title("W score nogen")
plt.savefig('W_nogen_reg.pdf')
